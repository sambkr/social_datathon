# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import string
import networkx as nx

# %%
def check_kw_freq(df, kws: list, op = 'or', attr = 'JOB_DESCRIPTION', verbose = False):
    
    kw_booltable = df[attr].str.contains(kws[0])
    for i in range(1, len(kws)):
        if op == 'or':
            kw_booltable =   kw_booltable | df[attr].str.contains(kws[i])
        else:
            kw_booltable =   kw_booltable & df[attr].str.contains(kws[i])
    
    if verbose:
        return kw_booltable
    else:
        return kw_booltable.sum()

# %%
def check_kw_freq_v2(df, kws: list, op = 'or', attr = 'JOB_DESCRIPTION'):
    
    kw_booltable = df[attr].str.contains(kws[0]).astype(int)
    for i in range(1, len(kws)):
        if op == 'or':
            kw_booltable =   kw_booltable + df[attr].str.contains(kws[i]).astype(int)
        else:
            kw_booltable =   kw_booltable * df[attr].str.contains(kws[i]).astype(int)
    
    return kw_booltable

# %%
postings_data = pd.read_csv('../social_datathon_0/UK_Postings_Sample.csv', low_memory=False)

# %%
postings_data.columns
# Out:
# Index([' ', 'POSTED', 'TITLE_NAME', 'SOC_4', 'SOC_4_NAME', 'SOC_3',
#        'SOC_3_NAME', 'SOC_2', 'SOC_2_NAME', 'LOT_OCCUPATION_NAME',
#        'LOT_CAREER_AREA_NAME', 'CITY_NAME', 'NUTS1_NAME', 'NUTS3_NAME',
#        'TTWA_NAME', 'COUNTRY_NAME', 'COMPANY_NAME', 'COMPANY_IS_STAFFING',
#        'UK_SIC_2', 'INDUSTRY', 'IS_INTERNSHIP', 'IS_REMOTE',
#        'SPECIALIZED_SKILLS_NAME', 'COMMON_SKILLS_NAME', 'SOFTWARE_SKILLS_NAME',
#        'CERTIFICATIONS_NAME', 'EDULEVELS_NAME_MIN', 'SALARY',
#        'JOB_DESCRIPTION'],
#       dtype='object')

# %%
for sk in ['SPECIALIZED_SKILLS_NAME', 'COMMON_SKILLS_NAME','SOFTWARE_SKILLS_NAME' ]:
    postings_data[sk] = postings_data[sk].astype(str)

postings_data['POSTED'] = pd.to_datetime(postings_data['POSTED'])
postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.lower()

# %%
postings_data= postings_data[~postings_data['JOB_DESCRIPTION'].isnull()]

# %%
N_jobs, N_attr = postings_data.shape
print(N_jobs)
# Out:
# 100000

# %%
postings_data['IS_REMOTE'].sum()/N_jobs
# Out:
# 0.0594

# %% [raw]
# punct = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{}~'   # `|` is not present here
# transtab = str.maketrans(dict.fromkeys(punct, ''))
#
# postings_data['JOB_DESCRIPTION'] = '|'.join(postings_data['JOB_DESCRIPTION'].tolist()).translate(transtab).split('|')

# %%
postings_data['JOB_DESCRIPTION']
# Out:
# 0         hplc laboratory supervisor\n\nposted by adzuna...
# 1         government engagement manager\nchiswick\n\ngre...
# 2         master (tug) - uk - permanent\n\nposted today ...
# 3         estates & technical services administrator\n\n...
# 4         independent audit deputy team leader - (dac)\n...
#                                 ...
# 100006    skilled production operative\n\nst. austell (f...
# 100007          job overview\n-accounts manager  aca / acca
# 100008    mechanical fitter\n\nrecruiter\n    bmr soluti...
# 100009    senior support worker - adult ld\n\nposted by ...
# 100010    book keeper\n\nrecruiter\n    absolute recruit...
# Name: JOB_DESCRIPTION, Length: 100000, dtype: object

# %%
postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace('(', ' ') 
postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace(')', ' ') 
postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace('.', ' ') 
postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace(',', ' ') 
postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace(';', ' ') 
postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace('-', ' ')
# Out:
# /var/folders/r1/0kzylldd4txdz1zgrvxrgpmh0000gn/T/ipykernel_31073/3680840724.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace('(', ' ')
# /var/folders/r1/0kzylldd4txdz1zgrvxrgpmh0000gn/T/ipykernel_31073/3680840724.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace(')', ' ')
# /var/folders/r1/0kzylldd4txdz1zgrvxrgpmh0000gn/T/ipykernel_31073/3680840724.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   postings_data['JOB_DESCRIPTION'] = postings_data['JOB_DESCRIPTION'].str.replace('.', ' ')

# %%
postings_data['EDULEVELS_NAME_MIN'].isnull().sum()/N_jobs
# Out:
# 0.80028

# %%
print(postings_data.loc[0]['JOB_DESCRIPTION'])
# Out:
# hplc laboratory supervisor
#
# posted by adzuna on 11/08/2021
#
# postcode
# south west
# gloucestershire
# gloucester
# chipping campden   gl55
#
# company name  adzuna
# category  scientific
# contract  permanent
# full/part time  full time
# salary  £ up to £30000 per annum
#
# description
#
# nscg are working in partnership with campden bri in the recruitment of a hplc supervisor  having been established for over 100 years  campden bri is well known for its breadth of services  with over 2 400 member companies  including the top 10 uk retailers and the top 15 global food & beverage manufacturers  clients view the organisation as an extension of their own in house technical team  reporting to the chromatography section manager  the hplc supervisor will undertake the analysis of samples in the hplc laboratory and all associated activities  management of the of the activities and operation of the hplc group  the role is primarily involved with the analysis of foods  and other matrices as required  by hplc  but can extend to other method of analysis the main duties of the role are  to supervise the operation of the hplc group  including but not limited to client contact  resources  training  reporting and technical excellence   40%  routine analysis of foodstuffs and associated materials using instrumental methods  in particular hplc  40%  dealing with non routine enquiries and requested for bespoke analysis by hplc for member and non member companies  10%  sample receipt steward  5%  basic calibration and maintenance of laboratory equipment  5%  this is an exciting opportunity to join a company who make a difference and help companies succeed through the services they supply  in order to be considered for the role you will  have a degree or equivalent experience in the field of analytical science possess extensive experience working in laboratory environment  with demonstrable experience in the area of hplc be competent in the operation and maintenance of hplc equipment demonstrate previous experience of managing a small team and training junior staff have proven effectiveness in managing timely and cost effective delivery of technical services as well as a starting base salary of up to £30 000 doe  campden bri offers a strong rewards package including com
#
# * ad id 222593374
# * last updated 11/08/2021
# * member since 22/04/2021
# * visitors 0

# %%
postings_data[postings_data['JOB_DESCRIPTION'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ , POSTED, TITLE_NAME, SOC_4, SOC_4_NAME, SOC_3, SOC_3_NAME, SOC_2, SOC_2_NAME, LOT_OCCUPATION_NAME, LOT_CAREER_AREA_NAME, CITY_NAME, NUTS1_NAME, NUTS3_NAME, TTWA_NAME, COUNTRY_NAME, COMPANY_NAME, COMPANY_IS_STAFFING, UK_SIC_2, INDUSTRY, IS_INTERNSHIP, IS_REMOTE, SPECIALIZED_SKILLS_NAME, COMMON_SKILLS_NAME, SOFTWARE_SKILLS_NAME, CERTIFICATIONS_NAME, EDULEVELS_NAME_MIN, SALARY, JOB_DESCRIPTION]
# Index: []
#
# [0 rows x 29 columns]

# %%
kws_list = [['green'], ['climate', 'climate-change', 'global warming'], ['renewable', 'renewables'], 
            ['renewable', 'renewables', 'green energy', 'wind power', 'wind energy', 'wind turbine', 'wind farm', 'wind turbines','solar power', 'solar energy', 'solar panels','solar panel', 'solar farm', 'solar farms', 'geothermal power', 'geothermal energy', 'tidal power', 'tidal energy'], 
            ['battery', 'batteries'], ['sustainable', 'sustainability'], ['carbon', 'low-carbon', 'carbon-neutral', 'carbon capture'], ['greenhouse', 'green house']]
kws_freq = [check_kw_freq(postings_data, kws) for kws in kws_list]

# %%
for idx, kws in enumerate(kws_list):
    print(kws, kws_freq[idx], '%.3g' % (kws_freq[idx]/N_jobs))
# Out:
# ['green'] 2764 0.0276
# ['climate', 'climate-change', 'global warming'] 592 0.00592
# ['renewable', 'renewables'] 659 0.00659
# ['renewable', 'renewables', 'green energy', 'wind power', 'wind energy', 'wind turbine', 'wind farm', 'wind turbines', 'solar power', 'solar energy', 'solar panels', 'solar panel', 'solar farm', 'solar farms', 'geothermal power', 'geothermal energy', 'tidal power', 'tidal energy'] 736 0.00736
# ['battery', 'batteries'] 218 0.00218
# ['sustainable', 'sustainability'] 3103 0.031
# ['carbon', 'low-carbon', 'carbon-neutral', 'carbon capture'] 762 0.00762
# ['greenhouse', 'green house'] 48 0.00048

# %%
(postings_data.COMPANY_NAME == 'Unclassified').sum()/N_jobs
# Out:
# 0.299767025627181

# %% [raw]
# print('False positive with sustainable keyword')
# print(postings_data[postings_data.COMPANY_NAME == 'West Sussex Golf Club,limited'].loc[312].JOB_DESCRIPTION)

# %% [raw]
# print('False positive with sustainable keyword')
# print(postings_data.JOB_DESCRIPTION[postings_data.COMPANY_NAME == 'West Sussex Golf Club,limited'].loc[312])

# %% [raw]
# false_positive_kws = ['cop', 'environment', 'sustainable']

# %%
renewable_energy_kws = set(['net zero','climate change', 'global warming', 'sustainable development', 'sustainability', 'renewable energy','renewable power', 'renewables', 'green energy', 
                        'green tech','green transition','green bonds', 
                        'carbon capture', 'decarbonisation', 'decarbonization',
                        'low carbon', 'carbon neutral', 'reduce carbon', 'carbon reduction',
                        'carbon footprint','zero carbon','carbon free',
                        'wind power', 'wind energy', 'wind turbine', 'wind farm', 'wind turbines','solar power', 'solar energy', 'solar panels','solar panel', 'solar farm', 'solar farms', 'geothermal power', 'geothermal energy', 'tidal power', 'tidal energy',  
                        'net zero', 'net-zero', 'cop', 'environmental protection', 'environmental conservation',
                        'ipcc', 'greenhouse gas', 
    'climate change mitigation', 'green house gas', 'greenhouse emission', 'green house emission', 'greenhouse emissions', 'green house emissions'])
renewable_energy_kws_filter = check_kw_freq_v2(postings_data, [kw + ' ' for kw in renewable_energy_kws], op='or')

# %%
print([(i+1, (renewable_energy_kws_filter > i).sum()) for i in range(len(renewable_energy_kws))])
# Out:
# [(1, 2208), (2, 519), (3, 173), (4, 61), (5, 25), (6, 9), (7, 4), (8, 1), (9, 1), (10, 0), (11, 0), (12, 0), (13, 0), (14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0), (20, 0), (21, 0), (22, 0), (23, 0), (24, 0), (25, 0), (26, 0), (27, 0), (28, 0), (29, 0), (30, 0), (31, 0), (32, 0), (33, 0), (34, 0), (35, 0), (36, 0), (37, 0), (38, 0), (39, 0), (40, 0), (41, 0), (42, 0), (43, 0), (44, 0), (45, 0), (46, 0), (47, 0), (48, 0), (49, 0)]

# %%
((renewable_energy_kws_filter > 1) & (postings_data.COMPANY_NAME != 'Unclassified')).sum()/N_jobs
# Out:
# 0.00417

# %%
renewable_energy_kws_comp_filter = (renewable_energy_kws_filter > 1) & (postings_data.COMPANY_NAME != 'Unclassified')
postings_data[renewable_energy_kws_comp_filter].COMPANY_NAME.nunique(), postings_data[renewable_energy_kws_comp_filter].COMPANY_NAME.nunique()/(postings_data.COMPANY_NAME.nunique()-1)
# Out:
# (263, 0.016457042738251673)

# %%
green_comps = postings_data[renewable_energy_kws_comp_filter].COMPANY_NAME.unique()

# %%
postings'SPECIALIZED_SKILLS_NAME'

# %%
spec_skill_core_green_split = [s[4:-2].replace('"', '').split(',\n  ') for s in postings_data[renewable_energy_kws_comp_filter]['SPECIALIZED_SKILLS_NAME'] if len(s) > 3 ]

# %%
spec_skill_core_green_counts = Counter([sk for joblst in spec_skill_core_green_split  for sk in joblst])

# %% [raw]
# green_skills = ['Green Building',  'Sustainability Reporting',
# 'Renewable Energy','Circular Economy','Environmental Engineering','Environmental Impact Assessments',
# 'Sustainable Materials','Regenerative Design', 'Environmental Issue', 'Energy Trading',
# 'Environmental Quality',  'Sustainability Initiatives',
# 'Sustainable Design', 'Environmental Policy','Energy Technology', 'Hydrogen Production', 'Environmental Laws',
# 'Sustainable Development','Emission Calculations', 'Wind Power','Nuclear Power', 'Climate Change Mitigation',
# 'Climate Variability And Change','Water Conservation','Electric Vehicles','Climatology','Environmentalism',
# 'Climate Policy','Renewable Energy Systems',  'Sustainable Business','Electric Vehicle (EV) Installation', 'Environmental Protocols','Environmental Auditing', 'Environmental Accounting',
# 'Environmental Mitigation', 'Wind Farming', 'Wind Turbines', 'Environmental Science',
# 'Environmental Consulting', 'Air Quality','Wind Turbine Maintenance',
#  'Environmental Monitoring', 'Habitat Improvement','Low Carbon Development',  'Marine Conservation', 'Climate Resilience', 'Renewable Energy Markets','Environmental Justice','Water Pollution',
#      'Climate Modeling', 'Wildlife Science', 'Wildlife Conservation', 'Solar Energy Systems Installation','Sustainability Planning', 'Sustainability Procedures','Energy Conservation Measures', 'Wind Turbine Technology',
#         'Reforestation', 'Energy Conservation', 'Net Zero', 'Carbon Footprint Reduction', 'Carbon Accounting','Low Carbon Solutions','Greenhouse Gas', 'Carbon Offsets','Carbon Management', 'Carbon Markets',  'Carbon Capture And Storage']

# %%
green_skills = ['Green Building',  'Sustainability Reporting',
'Renewable Energy','Circular Economy',
'Sustainable Materials','Regenerative Design', 'Energy Trading',  'Sustainability Initiatives',
'Sustainable Design','Hydrogen Production', 'Environmental Laws',
'Sustainable Development','Emission Calculations', 'Wind Power','Nuclear Power', 'Climate Change Mitigation',
'Climate Variability And Change','Electric Vehicles','Climatology',
'Climate Policy','Renewable Energy Systems',  'Sustainable Business','Electric Vehicle (EV) Installation', 
 'Wind Farming', 'Wind Turbines', 'Environmental Science',
'Wind Turbine Maintenance','Low Carbon Development',  'Climate Resilience', 'Renewable Energy Markets','Environmental Justice',
     'Climate Modeling','Solar Energy Systems Installation','Sustainability Planning', 'Sustainability Procedures', 'Wind Turbine Technology',
        'Reforestation', 'Net Zero', 'Carbon Footprint Reduction', 'Carbon Accounting','Low Carbon Solutions','Greenhouse Gas', 'Carbon Offsets','Carbon Management', 'Carbon Markets',  'Carbon Capture And Storage']

# %%
green_skill_jobs =postings_data[postings_data.SPECIALIZED_SKILLS_NAME.str.contains('|'.join(green_skills))]
# Out:
# /var/folders/r1/0kzylldd4txdz1zgrvxrgpmh0000gn/T/ipykernel_31073/4206332261.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   green_skill_jobs =postings_data[postings_data.SPECIALIZED_SKILLS_NAME.str.contains('|'.join(green_skills))]

# %%
len(green_skill_jobs)/N_jobs
# Out:
# 0.00539

# %%
spec_skill_green_skill_jobs_split = [(idx,s[4:-2].replace('"', '').split(',\n  ')) for (idx, s) in green_skill_jobs['SPECIALIZED_SKILLS_NAME'].items() if len(s) > 3 ]

# %%
green_skill_jobs_skill_counter = Counter([sk for joblst in spec_skill_green_skill_jobs_split for sk in joblst[1]])

# %%
green_skill_counter = {sk: green_skill_jobs_skill_counter[sk] for sk in green_skills}

# %%
prom_green_skills = [sk for sk in green_skill_counter if green_skill_counter[sk] > 2]

# %%
[(sk,green_skill_counter[sk]) for sk in prom_green_skills]
# Out:
# [('Green Building', 14),
#  ('Sustainability Reporting', 7),
#  ('Renewable Energy', 16),
#  ('Circular Economy', 12),
#  ('Energy Trading', 14),
#  ('Sustainability Initiatives', 19),
#  ('Sustainable Design', 6),
#  ('Hydrogen Production', 8),
#  ('Environmental Laws', 103),
#  ('Sustainable Development', 29),
#  ('Emission Calculations', 4),
#  ('Wind Power', 6),
#  ('Nuclear Power', 27),
#  ('Climate Variability And Change', 9),
#  ('Electric Vehicles', 83),
#  ('Climatology', 4),
#  ('Renewable Energy Systems', 3),
#  ('Sustainable Business', 18),
#  ('Wind Farming', 3),
#  ('Wind Turbines', 11),
#  ('Environmental Science', 78),
#  ('Wind Turbine Maintenance', 3),
#  ('Climate Resilience', 4),
#  ('Solar Energy Systems Installation', 3),
#  ('Sustainability Planning', 8),
#  ('Net Zero', 70),
#  ('Carbon Footprint Reduction', 14),
#  ('Carbon Accounting', 5),
#  ('Greenhouse Gas', 8),
#  ('Carbon Offsets', 3),
#  ('Carbon Management', 11),
#  ('Carbon Markets', 3),
#  ('Carbon Capture And Storage', 3)]

# %%
from networkx.algorithms import bipartite

# %%
B = nx.Graph()
B.add_nodes_from([e[0] for e in spec_skill_green_skill_jobs_split], bipartite=0)
B.add_nodes_from(set([sk for joblst in spec_skill_green_skill_jobs_split for sk in joblst[1]]), bipartite=1)
for e in spec_skill_green_skill_jobs_split:
    B.add_edges_from([(e[0], v) for v in e[1]])

# %%
skill_nodes = {n for n, d in B.nodes(data=True) if d["bipartite"] == 1}
P = bipartite.weighted_projected_graph(B, skill_nodes, ratio=False)

# %%
Green_skill_subgraph = P.subgraph([sk for sk in green_skill_counter if green_skill_counter[sk] > 2])
Green_skill_cc = max(nx.connected_components(Green_skill_subgraph ), key = len)

# %%
list(nx.connected_components(Green_skill_subgraph ))
# Out:
# [{'Carbon Accounting',
#   'Carbon Footprint Reduction',
#   'Carbon Management',
#   'Carbon Markets',
#   'Carbon Offsets',
#   'Circular Economy',
#   'Climate Resilience',
#   'Climate Variability And Change',
#   'Climatology',
#   'Electric Vehicles',
#   'Emission Calculations',
#   'Environmental Laws',
#   'Environmental Science',
#   'Green Building',
#   'Greenhouse Gas',
#   'Net Zero',
#   'Nuclear Power',
#   'Renewable Energy',
#   'Sustainability Initiatives',
#   'Sustainability Planning',
#   'Sustainability Reporting',
#   'Sustainable Business',
#   'Sustainable Design',
#   'Sustainable Development',
#   'Wind Power'},
#  {'Wind Farming', 'Wind Turbine Maintenance', 'Wind Turbines'},
#  {'Renewable Energy Systems'},
#  {'Solar Energy Systems Installation'},
#  {'Energy Trading'},
#  {'Carbon Capture And Storage', 'Hydrogen Production'}]

# %%
pos = nx.kamada_kawai_layout(Green_skill_subgraph.subgraph(Green_skill_cc), weight=True)

# %%
plt.figure(figsize= [16,9])

nx.draw(Green_skill_subgraph.subgraph(Green_skill_cc),pos= pos, node_size = 10, with_labels= True)

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
GB = B.edge_subgraph([e for e in B.edges() if e[1] in prom_green_skills])

# %%
GB_Mat = bipartite.biadjacency_matrix(B, row_order = prom_green_skills)

# %%
GB_Cov_Mat = np.cov(GB_Mat.todense())

# %%
plt.imshow(GB_Cov_Mat - np.diag(np.diag(GB_Cov_Mat)), vmin = -0.0015, vmax = 0.0015, cmap = 'bwr')
plt.colorbar()

# %%
r_idx, c_idx = np.where(GB_Cov_Mat - np.diag(np.diag(GB_Cov_Mat)) > 5e-4)
Cov_Filt_GS_subgraph = Green_skill_subgraph.edge_subgraph([(prom_green_skills[r_idx[j]], prom_green_skills[c]) for j, c in enumerate(c_idx) if r_idx[j] > c])

# %%
Cov_Filt_GS_subgraph_maximal = Cov_Filt_GS_subgraph.subgraph(max(nx.connected_components(Cov_Filt_GS_subgraph), key = len))

# %%
pos = nx.kamada_kawai_layout(Cov_Filt_GS_subgraph_maximal)
fig, ax = plt.subplots(1,1, figsize = [16,9])
nx.draw(Cov_Filt_GS_subgraph_maximal, node_size =10, pos= pos, with_labels= True, ax = ax)
fig.tight_layout()

# %%
n_components = 6
LDA = LatentDirichletAllocation(n_components = n_components )
LDA.fit(GB_Mat.T)
# Out:
# LatentDirichletAllocation(n_components=6)

# %%
for row in LDA.components_:
    print(sorted([(sk, row[idx]/np.sum(row))  for idx, sk in enumerate(prom_green_skills)  if  row[idx] > 1.01/n_components ], key = lambda x : x[1], reverse = True))
    print('-------')
# Out:
# [('Sustainable Development', 0.29914601124029994), ('Sustainability Initiatives', 0.19657848454544527), ('Energy Trading', 0.14530178119899295), ('Climate Variability And Change', 0.0940117214881016), ('Sustainability Planning', 0.08375806421905288), ('Greenhouse Gas', 0.06322426303364398), ('Climatology', 0.042735713836475946), ('Renewable Energy Systems', 0.0324790258771784)]
# -------
# [('Environmental Laws', 0.7457318740224957), ('Circular Economy', 0.07964338604669502), ('Sustainable Design', 0.04457134720747164), ('Wind Power', 0.044566655534597675), ('Sustainability Reporting', 0.03006351381160204), ('Carbon Capture And Storage', 0.022884170302176876)]
# -------
# [('Net Zero', 0.5815243139547699), ('Carbon Footprint Reduction', 0.11740670142911164), ('Carbon Management', 0.0842791140003348), ('Hydrogen Production', 0.06768192114144538), ('Carbon Accounting', 0.03456621315833789), ('Sustainability Reporting', 0.02629393838434592), ('Solar Energy Systems Installation', 0.026244498314709288), ('Circular Economy', 0.010897761754062209), ('Emission Calculations', 0.009667826041840988), ('Carbon Offsets', 0.009639122645531474)]
# -------
# [('Nuclear Power', 0.44171364827895726), ('Wind Turbines', 0.18156460884078574), ('Climate Resilience', 0.06774581669880518), ('Wind Farming', 0.05148844516043453), ('Wind Turbine Maintenance', 0.05148844516043366), ('Carbon Markets', 0.05148838042618785), ('Carbon Offsets', 0.035273936104487404), ('Greenhouse Gas', 0.035253979897055025), ('Carbon Management', 0.01892263741768128)]
# -------
# [('Environmental Science', 0.7935794481482868), ('Green Building', 0.143822879504316), ('Carbon Accounting', 0.011801472386697319)]
# -------
# [('Electric Vehicles', 0.6626822623618157), ('Sustainable Business', 0.1447524248994599), ('Renewable Energy', 0.12881785545785193), ('Emission Calculations', 0.02523342189041402)]
# -------

# %%
green_comp_green_job_counter = Counter(list(postings_data[renewable_energy_kws_comp_filter].COMPANY_NAME))
green_comp_total_job_counter= Counter(list(postings_data[postings_data.COMPANY_NAME.isin(green_comps)].COMPANY_NAME))

# %%
core_green_comps = [k for k, w in green_comp_green_job_counter.items() if w > 1]
peri_green_comps =  [k for k, w in green_comp_green_job_counter.items() if w== 1]

# %%
len(peri_green_comps), len(core_green_comps), len(green_comps)
# Out:
# (205, 58, 263)

# %%
all_green_jobs = postings_data[(renewable_energy_kws_filter > 1)]


peri_green_jobs = postings_data[postings_data.COMPANY_NAME.isin(peri_green_comps) & (renewable_energy_kws_filter > 1)]

core_green_jobs = postings_data[postings_data.COMPANY_NAME.isin(core_green_comps) & (renewable_energy_kws_filter > 1)]

# %%
sum(core_green_jobs.SOC_2.isnull()), sum(core_green_jobs.SOC_3.isnull()), sum(core_green_jobs.SOC_4.isnull())
# Out:
# (0, 0, 0)

# %%
for e in postings_data[(postings_data.COMPANY_NAME == 'Wwf')& (renewable_energy_kws_filter > 1)].JOB_DESCRIPTION:
    print(e)
# Out:
# eat4change project manager
#
# wwf
#
# 121 reviews
#
# woking
#
# ?32 291 a year
#
# wwf
#
# 121 reviews
#
# read what people are saying about working here
#
# job reference
#
# req000093
#
# date posted
#
# 29/03/2021
#
# application closing date
#
# 20/04/2021
#
# location
#
# woking
#
# salary
#
# ?32 291
#
# package
#
# blank
#
# job category/type
#
# commodities
#
# this is a unique opportunity to use your skills in developing and managing significant projects or programmes to save the planet  we have recently received funding to lead a project to engage european youth with sustainable diets  eat4change is a collaboration with several wwf network offices and the youth run non profit organisation aisec  we need you to help deliver this vital project to reduce the environmental impact of food consumed in europe and help achieve sustainable development goals and climate change treaties
#
# as project manager you will manage the development and delivery of our eat4change strategy  leading a small team  you will ensure activities are delivered against agreed schedules  milestones and objectives  in addition to creating work plans you will take overall responsibility for project progress  you will also produce project documentation and monitor budgets as well as provide regular project and financial reporting  whether commissioning research and managing relationships with external contractors or building the projects profile  you will play a key role in ensuring that eat4change is a success
#
# you must have an extensive background in project or programme management and experience of strategic planning and project development  skilled at managing multiple stakeholders  you will be effective at prioritising and executing projects effectively  this will include experience of reviewing and monitoring project plans and budgets  results orientated  you will also be comfortable managing and motivating a project team
#
# in addition  you will possess excellent communication  problem solving and influencing skills  able to work on your own initiative  you will be delivery focused with a passion for quality  experience of working in youth engagement and movement building as well as of working on eu funded projects would be highly desirable
#
# if you have the expertise we need and are excited about helping build a movement in defence of nature please visit our website via the link  complete the online registration and submit a copy of your up to date cv with cover letter highlighting why you are interested in this role and why you believe you are suited for the role
#
# every role at wwf is open to applications from all sections of society  we believe in the potential of everyone regardless of sex  race  religion or belief  ethnic origin  different physical ability  family structure  socio economics  age  nationality or citizenship  marital  domestic or civil partnership  sexual orientation  gender identity  or any other aspect that makes you  well you  here at wwf were committed to conscious inclusion that helps cultivate an ethos of belonging  connection and shared purpose  we believe that the more diverse we are the better we become  this brings us together and empowers us to develop  engage and inspire  and critically to help build a future where people can live in harmony with nature
#
# our policies and benefits reflect the importance of people being able to have a good work life balance and being able to bring their full self to work
#
# our world needs you like never before  we are the first generation to know we are destroying the world and we could be the last that can do anything about it  were looking for people who are passionate about making it politically  socially and economically unacceptable to destroy our planets natural resources  we need you to join us in the fight for our world
#
# wwf
#
# 1 day ago
#
# original job
#
# report job
#
# apply now
#
# apply on company site
#
# save this job
#
# save this job
# chief advisor  wildlife
#  wwf
#  woking  surrey
# published
# 03 04 2018
#
# chief advisor  wildlife
#
# living planet centre woking
#
# ?59 000pa
#
# woking gu21 4ll
#
# chief advisor   the role
#
# wwf uk is looking for a new chief advisor on wildlife issues  to join the science and policy team  the purpose of the team is to guide wwf uk to achieve greater impact and to ensure that wwf uk drives the external agenda on our priority conservation and sustainability issues  we do this by stepping away from the detail and seeing the bigger picture  by strengthening the organisation's strategies  by offering or finding the best evidence and expertise that can guide or support wwf's work  by seeking out new opportunities for influence  and by delivering cutting edge interventions which can help us to deliver against wwf uk's strategic goals
#
# as a member of our science and policy team you will take responsibility for leading our scientific understanding on global wildlife and wildlife issues  such as wildlife crime  climate and species interactions  and human wildlife conflict
#
# this will involve ensuring that we are up to date with  and have access to  leading international expertise and current evidence on wildlife conservation and that we are keeping ahead of the external debate  you will advise on policy development and guide colleagues in using this expertise and evidence to shape coherent and effective strategies for influencing governments  businesses and other stakeholders  you will input into the development  delivery and evaluation of our programmes  campaigns and communications in the uk  eu and our priority partner offices in other countries too
#
# you will also support the development of wwf uk and wwf international network strategies on wildlife conservation by providing advice and guidance  you will identify and engage with key external audiences  and develop cutting edge research programmes  the ability to build internal relationships and external networks will be important  so you become a strong voice for wwf in influential media  key conferences and political processes
#
# chief advisor   requirements
#
# you must hold a relevant qualification  ideally a phd  and/or equivalent experience in wildlife conservation science or policy  you will demonstrate a good grasp of current wildlife science and policy debates internationally  coupled with experience of providing strategic leadership to organisations and programmes  preferably on issues relating to wildlife  you will ideally possess expertise in acting as the lead specialist for an organisation as well as a history of achieving organisational objectives
#
# effective at influencing key political and business stakeholders and shaping policy debates  you will also possess excellent networking  communication and advocacy skills  you will have strong skills as a science communicator  and experience of working with the media  a team player  you are adept at overcoming obstacles and can demonstrate a commitment to the natural world and wwf's core mission
#
# who are we?
#
# wwf believes in a future where people and nature thrive
#
# best known as the world's leading conservation body  we've seen first hand how wildlife  the environment and human activity are all interlinked
#
# that's why our passion for safeguarding the natural world has to be backed up by other environmental action   tackling the global threat of climate change  through our big global campaigns like earth hour  and helping people to change the way they live to ease pressure on natural resources
#
# wwf is at the heart of global activities in all these areas  we have teams of highly skilled professionals working with governments  businesses and communities here in the uk and around the world
#
# chief advisor   how to apply
#
# please visit our website via the link and complete the online registration and submit a copy of your up to date cv with cover letter highlighting why you are interested in this role and why you believe you are suited for the role
#
# closing date: 08/04/2018
#
# at wwf uk we are committed to creating an inclusive working environment  where diversity is valued and there is equality of opportunity  we therefore welcome applications from all sections of the community and we offer a range of benefits to encourage a work life balance

# %%
SOC_2_core_green_company_count = core_green_jobs[['COMPANY_NAME', 'SOC_2_NAME']].groupby('SOC_2_NAME').count()
SOC_3_core_green_company_count = core_green_jobs[['COMPANY_NAME', 'SOC_3_NAME']].groupby('SOC_3_NAME').count()
SOC_4_core_green_company_count = core_green_jobs[['COMPANY_NAME', 'SOC_4_NAME']].groupby('SOC_4_NAME').count()

# %%
SOC_2_all_comp_count = postings_data[['COMPANY_NAME', 'SOC_2_NAME']].groupby('SOC_2_NAME').count()
SOC_3_all_comp_count = postings_data[['COMPANY_NAME', 'SOC_3_NAME']].groupby('SOC_3_NAME').count()
SOC_4_all_comp_count = postings_data[['COMPANY_NAME', 'SOC_4_NAME']].groupby('SOC_4_NAME').count()

# %%
SOC_2_green_comp_frac = {s: SOC_2_core_green_company_count.loc[s].item()/SOC_2_all_comp_count.loc[s].item() for s in SOC_2_core_green_company_count.index}
SOC_3_green_comp_frac = {s: SOC_3_core_green_company_count.loc[s].item()/SOC_3_all_comp_count.loc[s].item() for s in SOC_3_core_green_company_count.index}
SOC_4_green_comp_frac = {s: SOC_4_core_green_company_count.loc[s].item()/SOC_4_all_comp_count.loc[s].item() for s in SOC_4_core_green_company_count.index}

# %%
print(sorted([(k,w*100) for k,w in SOC_2_green_comp_frac.items()], key = lambda x: x[1], reverse = True))
print('======')
print(sorted([(k,w*100) for k,w in SOC_3_green_comp_frac.items()], key = lambda x: x[1], reverse = True))
print('======')
print(sorted([(k,w*100) for k,w in SOC_4_green_comp_frac.items()], key = lambda x: x[1], reverse = True))
# Out:
# [('Science, Research, Engineering and Technology Professionals', 0.44773815037826153), ('Health and Social Care Associate Professionals', 0.39447731755424065), ('Other Managers and Proprietors', 0.34118048447628796), ('Business, Media and Public Service Professionals', 0.2929483155471856), ('Textiles, Printing and Other Skilled Trades', 0.27114967462039047), ('Corporate Managers and Directors', 0.2505916747876932), ('Science, Engineering and Technology Associate Professionals', 0.22400597349262646), ('Health Professionals', 0.2161622879946791), ('Culture, Media and Sports Occupations', 0.21082220660576245), ('Business and Public Service Associate Professionals', 0.2074462277541216), ('Skilled Construction and Building Trades', 0.16906170752324598), ('Sales Occupations', 0.14919806042521447), ('Skilled Metal, Electrical and Electronic Trades', 0.1448225923244026), ('Administrative Occupations', 0.13473457289140395), ('Customer Service Occupations', 0.10787486515641855), ('Transport and Mobile Machine Drivers and Operatives', 0.10526315789473684), ('Teaching and Educational Professionals', 0.09019165727170236), ('Elementary Administration and Service Occupations', 0.08396305625524769), ('Process, Plant and Machine Operatives', 0.08006405124099279), ('Caring Personal Service Occupations', 0.03301964668978042)]
# ======
# [('Conservation and Environment Professionals', 4.3478260869565215), ('Other Skilled Trades', 2.0), ('Senior Officers in Protective Services', 1.9607843137254901), ('Chief Executives and Senior Officials', 1.5151515151515151), ('Skilled Metal, Electrical and Electronic Trades Supervisors', 1.2658227848101267), ('Natural and Social Science Professionals', 0.9887005649717515), ('Engineering Professionals', 0.718132854578097), ('Construction Operatives', 0.684931506849315), ('Welfare and Housing Associate Professionals', 0.5997001499250375), ('Sports and Fitness Occupations', 0.4629629629629629), ('Business, Research and Administrative Professionals', 0.4408985933235356), ('Managers and Proprietors in Other Services', 0.4206983592763988), ('Business, Finance and Related Associate Professionals', 0.37052284890901604), ('Science, Engineering and Production Technicians', 0.34258307639602603), ('Administrative Occupations: Records', 0.32573289902280134), ('Production Managers and Directors', 0.3), ('Managers and Directors in Transport and Logistics', 0.28735632183908044), ('Architects, Town Planners and Surveyors', 0.2871500358937545), ('Electrical and Electronic Trades', 0.2849002849002849), ('Nursing and Midwifery Professionals', 0.2619324796274738), ('Information Technology and Telecommunications Professionals', 0.2521779000458505), ('Administrative Occupations: Office Managers and Supervisors', 0.24875621890547264), ('Customer Service Managers and Supervisors', 0.2398081534772182), ('Health Associate Professionals', 0.234192037470726), ('Construction and Building Trades', 0.23228803716608595), ('Elementary Security Occupations', 0.22727272727272727), ('Elementary Cleaning Occupations', 0.22701475595913734), ('Media Professionals', 0.2257336343115124), ('Sales Related Occupations', 0.22038567493112945), ('Functional Managers and Directors', 0.2164970772894566), ('Quality and Regulatory Professionals', 0.21413276231263384), ('Sales, Marketing and Related Associate Professionals', 0.16260162601626016), ('Health Professionals', 0.15552099533437014), ('Public Services and Other Associate Professionals', 0.1549186676994578), ('Therapy Professionals', 0.15408320493066258), ('Artistic, Literary and Media Occupations', 0.15015015015015015), ('Road Transport Drivers', 0.13245033112582782), ('Other Administrative Occupations', 0.10348395998620215), ('Information Technology Technicians', 0.09332711152589827), ('Teaching and Educational Professionals', 0.09019165727170236), ('Customer Service Occupations', 0.08460236886632826), ('Elementary Storage Occupations', 0.08424599831508003), ('Caring Personal Services', 0.05230125523012552), ('Administrative Occupations: Finance', 0.04194630872483222)]
# ======
# [('Sports players', 11.11111111111111), ('Environment professionals', 6.25), ('Production managers and directors in mining and energy', 6.0606060606060606), ('Road construction operatives', 5.88235294117647), ('Financial and accounting technicians', 5.0), ('Electrical and electronics technicians', 3.9473684210526314), ('Senior officers in fire, ambulance, prison and related services', 3.8461538461538463), ('Town planning officers', 3.3333333333333335), ('Other skilled trades n.e.c.', 2.2522522522522523), ('Public services associate professionals', 2.2222222222222223), ('Refuse and salvage occupations', 2.127659574468085), ('Brokers', 2.0408163265306123), ('Midwives', 1.7241379310344827), ('Design and development engineers', 1.6835016835016834), ('Chief executives and senior officials', 1.6483516483516485), ('Counsellors', 1.6260162601626018), ('Paramedics', 1.5873015873015872), ('Telephonists', 1.3333333333333335), ('Biological scientists and biochemists', 1.3262599469496021), ('Skilled metal, electrical and electronic trades supervisors', 1.2658227848101267), ('Social and humanities scientists', 1.2658227848101267), ('Engineering professionals n.e.c.', 1.142263759086189), ('Artists', 1.0526315789473684), ('Production and process engineers', 0.9615384615384616), ('Business and related research professionals', 0.9174311926605505), ('Construction project managers and related professionals', 0.8902077151335311), ('Further education teaching professionals', 0.8771929824561403), ('Office supervisors', 0.7874015748031495), ('Insurance underwriters', 0.7142857142857143), ('Business and financial project management professionals', 0.7128309572301426), ('Laboratory technicians', 0.6944444444444444), ('Chemical scientists', 0.6896551724137931), ('Business and related associate professionals n.e.c.', 0.6666666666666667), ('Transport and distribution clerks and assistants', 0.6666666666666667), ('Management consultants and business analysts', 0.6329113924050633), ('Welfare and housing associate professionals n.e.c.', 0.6153846153846154), ('Electronics engineers', 0.6134969325153374), ('Construction and building trades n.e.c.', 0.5747126436781609), ('Health and safety officers', 0.5420054200542005), ('Managers and proprietors in other services n.e.c.', 0.5151983513652756), ('IT project and programme managers', 0.5059021922428331), ('Electricians and electrical fitters', 0.5), ('Financial accounts managers', 0.48543689320388345), ('Managers and directors in storage and warehousing', 0.4629629629629629), ('Electrical engineers', 0.4524886877828055), ('Information technology and telecommunications directors', 0.45045045045045046), ('Occupational therapists', 0.4484304932735426), ('Pharmacists', 0.4405286343612335), ('Sports coaches, instructors and officials', 0.4291845493562232), ('Public relations professionals', 0.4098360655737705), ('Information technology and telecommunications professionals n.e.c.', 0.40444893832153694), ('Medical and dental technicians', 0.38022813688212925), ('Stock control clerks and assistants', 0.37593984962406013), ('Estate agents and auctioneers', 0.35842293906810035), ('Planning, process and production technicians', 0.3436426116838488), ('Business, research and administrative professionals n.e.c.', 0.33444816053511706), ('Senior professionals of educational establishments', 0.3246753246753247), ('Plumbers and heating and ventilating engineers', 0.3067484662576687), ('Civil engineers', 0.2976190476190476), ('Marketing and sales directors', 0.2957121734844751), ('Estimators, valuers and assessors', 0.2724795640326975), ('Quality control and planning engineers', 0.2702702702702703), ('Nursing auxiliaries and assistants', 0.2695417789757413), ('Security guards and related occupations', 0.267379679144385), ('IT business analysts, architects and systems designers', 0.26638252530633993), ('Medical practitioners', 0.2621231979030144), ('Engineering technicians', 0.25510204081632654), ('Customer service managers and supe ...

# %%
# Out:
# 10

# %%
Counter(list(core_green_jobs['SOC_3_NAME']))
# Out:
# Counter({'Information Technology and Telecommunications Professionals': 22,
#          'Managers and Proprietors in Other Services': 10,
#          'Business, Research and Administrative Professionals': 21,
#          'Functional Managers and Directors': 10,
#          'Managers and Directors in Transport and Logistics': 1,
#          'Sports and Fitness Occupations': 2,
#          'Other Skilled Trades': 5,
#          'Caring Personal Services': 2,
#          'Teaching and Educational Professionals': 4,
#          'Chief Executives and Senior Officials': 3,
#          'Natural and Social Science Professionals': 7,
#          'Sales Related Occupations': 8,
#          'Customer Service Occupations': 2,
#          'Nursing and Midwifery Professionals': 9,
#          'Administrative Occupations: Records': 4,
#          'Engineering Professionals': 24,
#          'Conservation and Environment Professionals': 5,
#          'Electrical and Electronic Trades': 3,
#          'Welfare and Housing Associate Professionals': 4,
#          'Therapy Professionals': 1,
#          'Business, Finance and Related Associate Professionals': 9,
#          'Media Professionals': 1,
#          'Public Services and Other Associate Professionals': 4,
#          'Elementary Security Occupations': 1,
#          'Health Professionals': 3,
#          'Health Associate Professionals': 2,
#          'Science, Engineering and Production Technicians': 10,
#          'Construction and Building Trades': 2,
#          'Production Managers and Directors': 3,
#          'Sales, Marketing and Related Associate Professionals': 6,
#          'Architects, Town Planners and Surveyors': 4,
#          'Other Administrative Occupations': 3,
#          'Administrative Occupations: Office Managers and Supervisors': 2,
#          'Quality and Regulatory Professionals': 2,
#          'Elementary Cleaning Occupations': 2,
#          'Information Technology Technicians': 2,
#          'Construction Operatives': 1,
#          'Customer Service Managers and Supervisors': 1,
#          'Senior Officers in Protective Services': 1,
#          'Artistic, Literary and Media Occupations': 1,
#          'Road Transport Drivers': 2,
#          'Elementary Storage Occupations': 1,
#          'Administrative Occupations: Finance': 1,
#          'Skilled Metal, Electrical and Electronic Trades Supervisors': 1})

# %%
for company_eg in core_green_comps:
    print(company_eg)
    for entry in postings_data.JOB_DESCRIPTION[postings_data.COMPANY_NAME == company_eg]:
        kw_intersect = [kw for kw in renewable_energy_kws if kw+ ' ' in entry]
        if len(kw_intersect) > 1:
            print(kw_intersect)
            #print(entry)

            print('----')
    print('================')
# Out:
# Deloitte
# ['low carbon', 'sustainability', 'net zero']
# ----
# ['zero carbon', 'sustainability', 'net zero']
# ----
# ================
# Penguin Recruitment
# ['carbon footprint', 'zero carbon', 'sustainability', 'carbon reduction', 'net zero']
# ----
# ['low carbon', 'sustainability']
# ----
# ['sustainability', 'renewables']
# ----
# ================
# University Of Southampton
# ['sustainability', 'sustainable development']
# ----
# ['low carbon', 'renewable energy']
# ----
# ================
# Equal Approach Limited
# ['sustainability', 'renewable energy', 'renewables', 'wind turbines', 'net zero']
# ----
# ['renewable energy', 'renewables']
# ----
# ================
# National Highways
# ['low carbon', 'net zero']
# ----
# ['low carbon', 'sustainable development']
# ----
# ================
# Macquarie
# ['green energy', 'renewables']
# ----
# ['green energy', 'renewables']
# ----
# ['zero carbon', 'renewable energy', 'carbon free']
# ----
# ['green energy', 'renewable energy', 'renewables']
# ----
# ['green energy', 'renewables']
# ----
# ================
# Verisk Analytics
# ['sustainability', 'climate change']
# ----
# ['wind power', 'renewable energy', 'renewables']
# ----
# ['sustainability', 'climate change']
# ----
# ================
# Sse Plc
# ['low carbon', 'renewable energy', 'net zero']
# ----
# ['low carbon', 'net zero']
# ----
# ['zero carbon', 'low carbon', 'carbon capture', 'net zero']
# ----
# ['zero carbon', 'wind power', 'low carbon', 'renewable energy', 'renewables', 'wind energy']
# ----
# ['wind farm', 'low carbon', 'renewable energy', 'renewables', 'net zero']
# ----
# ['low carbon', 'net zero']
# ----
# ['wind farm', 'renewable energy', 'renewables', 'net zero']
# ----
# ['low carbon', 'net zero']
# ----
# ['renewable energy', 'renewables']
# ----
# ['climate change', 'net zero']
# ----
# ['low carbon', 'renewable energy', 'net zero']
# ----
# ['low carbon', 'renewable energy', 'net zero']
# ----
# ['low carbon', 'renewable energy', 'net zero']
# ----
# ['low carbon', 'renewable energy', 'renewables']
# ----
# ['low carbon', 'carbon capture', 'net zero']
# ----
# ['low carbon', 'renewable energy', 'net zero']
# ----
# ['zero carbon', 'sustainability', 'climate change']
# ----
# ================
# NHS
# ['sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ['carbon footprint', 'sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['sustainability', 'carbon reduction']
# ----
# ['sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['carbon footprint', 'zero carbon', 'sustainability', 'net zero']
# ----
# ['zero carbon', 'sustainability', 'carbon reduction', 'climate change', 'net zero']
# ----
# ================
# John Wiley & Sons
# ['sustainability', 'sustainable development']
# ----
# ['low carbon', 'sustainability']
# ----
# ================
# Baker Hughes
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ================
# General Electric
# ['renewable energy', 'renewables']
# ----
# ['renewable energy', 'renewables', 'solar power']
# ----
# ['renewable energy', 'renewables']
# ----
# ================
# Unilever
# ['sustainability', 'climate change']
# ----
# ['sustainability', 'climate change']
# ----
# ================
# Shell
# ['renewables', 'climate change']
# ----
# ['renewables', 'climate change']
# ----
# ================
# Babcock International Group
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['low carbon', 'reduce carbon']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ================
# Ricardo Energy & Environment
# ['sustainability', 'climate change']
# ----
# ['sustainability', 'climate change']
# ----
# ================
# Jewson
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ================
# Edf Energy
# ['low carbon', 'climate change', 'net zero']
# ----
# ['low carbon', 'net zero']
# ----
# ['wind power', 'renewables', 'climate change', 'net zero']
# ----
# ['climate change', 'net zero']
# ----
# ['low carbon', 'renewables', 'wind energy']
# ----
# ['renewables', 'climate change', 'net zero']
# ----
# ================
# Leeds City Council
# ['zero carbon', 'low carbon', 'climate change']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ================
# Morson International
# ['zero carbon', 'net zero']
# ----
# ['sustainability', 'renewable energy']
# ----
# ['sustainability', 'renewable energy']
# ----
# ['zero carbon', 'net zero']
# ----
# ['sustainability', 'renewable energy']
# ----
# ['sustainability', 'renewable energy']
# ----
# ================
# Saint
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ================
# London Stock Exchange
# ['sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ================
# Nottingham Trent University
# ['sustainability', 'sustainable development']
# ----
# ['carbon reduction', 'reduce carbon']
# ----
# ================
# Airbus
# ['zero carbon', 'sustainability']
# ----
# ['zero carbon', 'sustainability']
# ----
# ['zero carbon', 'sustainability']
# ----
# ================
# Good Energy Group PLC
# ['renewable energy', 'climate change']
# ----
# ['zero carbon', 'renewable power', 'net zero']
# ----
# ================
# Sgn
# ['carbon footprint', 'net zero']
# ----
# ['carbon footprint', 'net zero']
# ----
# ================
# Suez Uk Environment LTD
# ['low carbon', 'sustainable development']
# ----
# ['low carbon', 'sustainable development']
# ----
# ================
# BP
# ['low carbon', 'sustainability', 'renewables', 'net zero']
# ----
# ['renewables', 'net zero']
# ----
# ['zero carbon', 'renewable energy', 'net zero']
# ----
# ['low carbon', 'net zero']
# ----
# ['carbon footprint', 'low carbon', 'carbon capture', 'net zero', 'reduce carbon']
# ----
# ['cop', 'net zero']
# ----
# ================
# SNC-Lavalin
# ['low carbon', 'net zero']
# ----
# ['renewables', 'decarbonisation', 'net zero']
# ----
# ['sustainability', 'climate change']
# ----
# ['renewables', 'decarbonisation', 'net zero']
# ----
# ================
# University College London
# ['sustainability', 'climate change']
# ----
# ['zero carbon', 'sustainability', 'net zero']
# ----
# ================
# National Grid
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'wind turbine', 'renewable energy']
# ----
# ['green energy', 'climate change']
# ----
# ================
# Derbyshire County Council
# ['zero carbon', 'sustainability']
# ----
# ['sustainability', 'carbon neutral']
# ----
# ================
# Rise Technical Recruitment Ltd
# ['renewables', 'solar farms']
# ----
# ['carbon footprint', 'green energy', 'sustainability', 'renewable energy', 'decarbonization', 'decarbonisation', 'carbon reduction', 'climate change', 'net zero']
# ----
# ['solar panels', 'solar panel']
# ----
# ['sustainability', 'renewable energy', 'renewables', 'net zero']
# ----
# ['green energy', 'renewable energy']
# ----
# ['wind turbine', 'wind turbines']
# ----
# ['renewable energy', 'renewables']
# ----
# ['renewable energy', 'renewables', 'net zero']
# ----
# ['renewables', 'carbon neutral']
# ----
# ['carbon footprint', 'renewable energy']
# ----
# ['renewable energy', 'renewables']
# ----
# ['renewable energy', 'renewables']
# ----
# ================
# Acre Resources
# ['zero carbon', 'sustainability', 'sustainable development']
# ----
# ['sustainability', 'net zero']
# ----
# ================
# Res Agency
# ['zero carbon', 'renewable energy']
# ----
# ['zero carbon', 'renewable energy']
# ----
# ['zero carbon', 'renewable energy', 'renewables']
# ----
# ['zero carbon', 'renewable energy']
# ----
# ================
# University Of Cambridge
# ['climate change mitigation', 'climate change']
# ----
# ['zero carbon', 'sustainability', 'climate change']
# ----
# ================
# Environment Agency
# ['sustainability', 'climate change']
# ----
# ['zero carbon', 'net zero']
# ----
# ['sustainability', 'climate change']
# ----
# ================
# Babcock International
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ================
# Jacobs Engineering Group
# ['sustainability', 'renewable energy', 'climate change']
# ----
# ['carbon footprint', 'zero carbon', 'low carbon', 'sustainability', 'decarbonisation', 'climate change', 'net zero']
# ----
# ['zero carbon', 'low carbon', 'net zero']
# ----
# ['low carbon', 'sustainability', 'renewable energy', 'climate change']
# ----
# ================
# Equilon Enterprises
# ['low carbon', 'renewable energy']
# ----
# ['renewables', 'climate change']
# ----
# ================
# Michael Page
# ['sustainability', 'sustainable development']
# ----
# ['low carbon', 'sustainability']
# ----
# ['zero carbon', 'sustainability']
# ----
# ================
# ManpowerGroup
# ['zero carbon', 'net zero']
# ----
# ['zero carbon', 'net zero']
# ----
# ================
# Wwf
# ['sustainable development', 'climate change']
# ----
# ['sustainability', 'climate change']
# ----
# ================
# PIB Group
# ['carbon footprint', 'climate change']
# ----
# ['carbon footprint', 'climate change']
# ----
# ================
# AECOM
# ['low carbon', 'carbon capture']
# ----
# ['sustainability', 'renewables', 'carbon capture']
# ----
# ['sustainability', 'renewables', 'carbon capture']
# ----
# ['low carbon', 'sustainability']
# ----
# ['sustainability', 'carbon capture', 'net zero']
# ----
# ================
# Heriot-Watt University
# ['low carbon', 'sustainability', 'net zero']
# ----
# ['sustainability', 'decarbonisation']
# ----
# ['zero carbon', 'low carbon', 'greenhouse gas', 'decarbonisation', 'net zero']
# ----
# ================
# Speedy Hire
# ['carbon footprint', 'sustainability']
# ----
# ['carbon footprint', 'sustainability']
# ----
# ================
# Parkinson Gray Associates LTD
# ['zero carbon', 'low carbon', 'sustainability', 'renewable energy']
# ----
# ['low carbon', 'sustainability']
# ----
# ================
# Wood Mackenzie
# ['sustainability', 'greenhouse gas', 'renewables', 'climate change']
# ----
# ['sustainability', 'renewables', 'climate change']
# ----
# ['sustainability', 'renewables', 'climate change']
# ----
# ================
# Iberdrola
# ['wind power', 'sustainability', 'climate change']
# ----
# ['wind power', 'sustainability', 'renewable energy', 'wind energy', 'climate change', 'net zero', 'reduce carbon']
# ----
# ================
# Siemens
# ['wind farm', 'wind power', 'wind turbine', 'renewable energy', 'wind turbines']
# ----
# ['sustainability', 'net zero']
# ----
# ['green energy', 'wind turbine', 'renewable energy']
# ----
# ================
# Ameresco
# ['renewable energy', 'carbon neutral']
# ----
# ['sustainability', 'renewable energy']
# ----
# ================
# Scottish Power Limited
# ['wind power', 'sustainability', 'renewable energy', 'renewables', 'wind energy', 'climate change']
# ----
# ['cop', 'wind power', 'sustainability', 'renewable energy', 'wind energy', 'climate change']
# ----
# ================
# AXA
# ['greenhouse gas', 'net zero']
# ----
# ['carbon footprint', 'climate change']
# ----
# ================
# @Work International
# ['cop', 'climate change']
# ----
# ['wind turbine', 'wind turbines']
# ----
# ================
# Brook Street Bureau PLC
# ['sustainability', 'net zero']
# ----
# ['sustainability', 'net zero']
# ----
# ================
# Ricardo.At Gmbh
# ['sustainability', 'climate change']
# ----
# ['sustainability', 'renewable energy', 'decarbonisation', 'climate change']
# ----
# ================
# Imperial College London
# ['sustainable development', 'climate change']
# ----
# ['zero carbon', 'sustainability']
# ----
# ================

# %%
print('False positive with sustainable keyword')
company_eg = "Everton Football Club"
for entry in postings_data.JOB_DESCRIPTION[postings_data.COMPANY_NAME == company_eg]:
    #print(set(entry.replace('\n', ' ').split(' ')).intersection(renewable_energy_kws))
    print([kw for kw in false_positive_kws if kw in entry])
    print('----')
# Out:
# False positive with sustainable keyword
# ['cop']
# ----
# []
# ----

# %%
company_eg = "Yo! Sushi"
for entry in postings_data.JOB_DESCRIPTION[(postings_data.COMPANY_NAME == company_eg) & renewable_energy_kws_filter]:
    #print(set(entry.replace('\n', ' ').split(' ')).intersection(renewable_energy_kws))
    print([kw for kw in renewable_energy_kws if kw in entry])
    print(entry)
    print('----')
# Out:
# ['sustainability']
# kitchen porter 287 reviews greenhithe da9 9.50 an hour - full-time yo sushi 287 reviews read what people are saying about working here. job details salary 9.50 an hour job type full-time benefits pulled from the full job description discounted or free food employee discount gym membership full job description yo! kitchen porter hourly rate: 9.50 as part of our squad working as a kitchen porter, you'll enjoy: fantastic working hours - no midnight finishes here! power your shift with full choice of free yo! food on your paid break opportunity to grow with yo! we will pay for you to achieve professional qualifications (up to degree level) whilst you work brilliant support services designed to enhance your physical, mental and financial wellbeing bespoke reward platform including access to retail, cinema & gym discounts 50% off your food every time you dine with us for you and 3 friends our business is expanding meaning we can offer you job security and the opportunity to grow your career alongside us contribute towards our award-winning sustainability initiatives that delivers progress against 9 un sustainability goals no experience? no problem! we'll teach you what it means to deliver great results through fantastic food and engaged guests! what you'll be doing: own it: we're proud to give everyone the opportunity to become a yo! pro, mastering the operation, cleanliness, and procedures of your section care about it: you'll ensure your restaurant is the cleanest, most organised venue in town! make it exceptional: you'll act as a role model to your squad, setting high standards of cleanliness and ensuring a smooth running operation win together: celebrate global success across our group: 1500 kiosks across yo!, panku, mai taiko snowfox & bento 60 yo! restaurants 50 major retail partners 3700 locations globally from hawaii to aberdeen ready to roll? in your previous life, you may have been a kitchen porter, kitchen assistant or restaurant assistant. at yo! we don't believe in a foh / boh divide, we are one squad. become a kitchen porter today and bring people together to celebrate better food for everyone the japanese way. hiring insights job activity posted today yosushi
# ----
# ['sustainability']
# team leader - panku yo! sushi frome, somerset 10.50 per hour permanent full-time just now our kiosk is located inside asda superstore, in frome ba115la team leader- panku kiosk hourly rate 10.50/hr become a panku pro and join the yo! group, pioneering our new concept, bringing restaurant quality sushi and sensational street food to an asda supermarket near you. we're proud to offer our kiosk team leaders: fantastic working hours with no late nights power your shift with full choice of free yo! food on your paid break opportunity to grow with yo! we will pay for you to achieve professional qualifications (up to degree level) whilst you work brilliant support services designed to enhance your physical, mental, and financial wellbeing bespoke reward platform including access to retail, cinema & gym discounts 50% off your food every time you dine with us for you and 3 friends our business is expanding meaning we can offer you job security and the opportunity to grow your career alongside us contribute towards our award-winning sustainability initiatives that delivers progress against 9 un sustainability goals what you'll be doing: own it: we're proud to give everyone the opportunity to become a yo! pro, we'll teach you what it means to master our menus care about it: you'll support your team to follow your lead and love what they do, promoting our culture of collaboration, initiative, and teamwork make it exceptional: make people smile and master the art of great japanese food win together: celebrate global success across our group: 1500 kiosks across yo!, panku, mai taiko snowfox & bento 60 yo! restaurants 50 major retail partners 3700 locations globally from hawaii to aberdeen ready to roll? in your previous life you may have been a foh/boh team leader, supervisor, cdp, junior sous chef, crew member, sous chef, deputy manager come roll with us as a kiosk team leader, and you'll be playing a key role by bringing people together to celebrate better food for everyone the japanese way... yo! sushi apply now forward this job to your email to apply later share similar jobs customer experience team leader save mole valley farmers frome, somerset job title: customer experience team leadercontract type: permanenthours: full time - 37.5 hours per week looking for a job that gives you the security of working for a big compan 27 days ago more... view similar jobs: customer team leader jobs in frome jobs in frome customer experience team leader save mole valley farmers frome, somerset the vacancy job title: customer experience team leader contract type: permanent hours: full time - 37.5 hours per week looking for a job that gives you the security of workin 26 days ago more... view similar jobs: customer team leader jobs in frome jobs in frome team leader save superdrug warminster, wiltshire 10.00 per hour why superdrug? passionate about beauty and health? good motivator? can you keep it fun for your team when the pressure's on? leading your team, hitting targets, progressing your 5 days ago apply easily more... view similar jobs: team leader jobs in warminster jobs in warminster sign in
# ----

# %%
print('False positive with sustainable keyword')
company_eg = "Thomas Cook"
for entry in postings_data.JOB_DESCRIPTION[(postings_data.COMPANY_NAME == company_eg) & renewable_energy_kws_filter]:
    #print(set(entry.replace('\n', ' ').split(' ')).intersection(renewable_energy_kws))
    print([kw for kw in renewable_energy_kws if kw in entry])
    print(entry)
    print('----')
# Out:
# False positive with sustainable keyword
# ['sustainability']
# location :  manchester - united kingdom
# type :  permanent jobs
# salary :  competitive
# main industry :  search aerospace jobs
# job id :  84952665
# advertiser :  thomas cook
# posted on :  06 september 2018 06/10/2018
#
# over 175 years ago, our founder thomas cook began this company with a vision to 'broaden the mind of others and break down the partition walls of prejudice.'
#
# once describing himself as 'the willing and devoted servant of the travelling public,' thomas cook was a true pioneer of the travel industry, opening up a world of new destinations and new travel experiences to everyone. by obtaining the best services and prices for his customers, he laid the foundations of the company that still bears his name today.
#
# thomas cook is now one of the world's leading leisure travel groups, supported by around 22,000 colleagues and operating from 15 countries.
#
# our vision today remains true to thomas cook's ambitions - to be the world's most loved holiday company.
#
# role: group airlines operational efficiencies analyst (non pilot role)
#
# location: manchester based
#
# working hours: 37.5
#
# job purpose: the role will support the operational efficiencies manager in delivering the thomas cook group flight operations efficiency initiatives
#
# key responsibilities:
#
# -support the operational efficiencies manager in the delivery of the thomas cook group flight operations efficiency initiatives (coordination of the fuel efficiency programs in all the group airlines). lead certain efficiency projects across group flight operations as and when required.
# -analyse operational data to support operational efficiency projects and kpi measurement.
# -provide communications material that is relevant to different audiences across the group airlines & produce reporting material that will go the flight operations leadership team as well as other management boards across the airlines.
# -analyse data in accordance with the company procedures for annual carbon submissions for eu ets emission trading scheme as well as corsia (carbon offsetting & reduction scheme for international aviation). assist in the development of new procedures.
# -provide support on projects related to the wider thomas cook group sustainability strategy when flight operations involvement is relevant.
#
# key performance indicators
#
# -fuel efficiency reports produced on schedule.
# -analysis of eu ets & corsia emissions data completed accurately.
# -successful delivery of key efficiency projects.
#
# capabilities profile  technical skills/knowledge, experience & track record.
#
# must have:
#
# -excellent communication and analytical skills.
# -proficient user of ms excel & comfortable with numerical data.
# -keen interest in the aviation industry.
# -affinity for new cultures and an international work environment, along with willingness to travel between all aoc bases in uk/de/dk/es.
#
# preferred:
#
# -strong numeracy skills and a technical degree background.
# -computer programming skills (vba).
# -airline operations knowledge.
# -lean knowledge and operational improvement/process mapping experience.
#
# qualifications, training, professional memberships or accreditations
#
# -educated to degree level  technical subject.
#
# dotted line reports / key stakeholders:
#
# -director group airlines flight operations compliance, risk, and standards.
# -head of flight ops engineering support
# -fleet managers
# -training managers
# -gmo/ground operations/cabin services.
#
# closing date:
#
# 26 september 2018
#
# life at thomas cook is fast-paced and full of opportunities. as an internal colleague we are dedicated to ensuring you can fulfill your career aspirations, youll be given the support and training you need to develop your career in the direction you choose.
#
# if you require any support during the recruitment process, your local hr/ resourcing team and they will be happy to help.
# -ul
#
# apply :
#
# your email address :
# your country of residence :
#
# never supply bank or financial information to advertisers. if bank details or money are requested for a job vacancy, email support@tiptopjob.com.
# ----

# %%
list(green_comps)
# Out:
# ['Deloitte',
#  'National Grid',
#  'Bond Williams',
#  'Michael Page',
#  'Unclassified',
#  'Mountain Warehouse',
#  'Austin Fraser',
#  'Cs&Co.',
#  'Penguin Recruitment',
#  'Talent Spa',
#  'Companies House',
#  'Chc Group Ltd.',
#  'Cadent Gas Limited',
#  'Drax Group',
#  'HMRC',
#  'Aker Solutions',
#  'University Of Southampton',
#  'Four Paws Uk',
#  'Sse Plc',
#  'First People Solutions',
#  'Appcast',
#  'Atos',
#  'Worleyparsons',
#  'Harbour Hotel Limited',
#  'Mace Group',
#  'Oracle',
#  'J Tomlinson Limited',
#  'Blue Octopus Recruitment',
#  'Equal Approach Limited',
#  'Kirklees Council',
#  'National Highways',
#  'Fortive',
#  'G2 Legal',
#  'Cms Group',
#  'Thomas Cook',
#  'NHS',
#  'Carbon60',
#  'Iwm-Gmbh',
#  'Eden Scott',
#  'Macquarie',
#  'Cyan Partners, Lp',
#  'Recruitment Genius Limited',
#  'Robert Half',
#  'P.A Consulting',
#  'Arts University Bournemouth',
#  'SPIE Personalmanagement',
#  'Natura',
#  'Service Care Solutions',
#  'Vet Seekers LTD',
#  'Henry Nicholas Associates',
#  'PricewaterhouseCoopers',
#  'Oxwash',
#  'Arcadis',
#  'Magenta',
#  'The Shakespeare Birthplace Trust',
#  'Alexa Capital',
#  'Lancaster City Council',
#  'Rendall And Rittner Limited',
#  'Verisk Analytics',
#  'Tlt',
#  'Save Children Cicmc',
#  'Essential Employment',
#  'Kier Group',
#  'Mha Macintyre Hudson',
#  'Ofgem',
#  'Milton Keynes Council',
#  'Depop',
#  'Randstad',
#  'We Are Ssg',
#  '300 North',
#  'Mitchell Maguire Ltd',
#  'The Ofs Group',
#  'Octopus',
#  'Co-operative Group',
#  'Ernst & Young',
#  'Sr2',
#  'Forman And Brown Development Co.',
#  'Brunning And Price Ltd',
#  'Foster Wheeler',
#  'Omega Resource Group',
#  'Ovo Energy',
#  'Amazon',
#  'Axis Group',
#  'Leicestershire County Council',
#  'Vale Of Glamorgan Council',
#  'Resourcing',
#  'Bond Creative Agency',
#  'Enva',
#  'Severn Trent',
#  'Reed',
#  'John Wiley & Sons',
#  'Langland Consultants LTD',
#  'Baker Hughes',
#  'Mondelez International',
#  'General Electric',
#  'E.ON Group',
#  'Unilever',
#  'Hays',
#  'Utility Trading LTD',
#  'Molson Coors',
#  'Shell',
#  'Essex County Council',
#  'Babcock International Group',
#  'Reed In Partnership',
#  'Tameside College',
#  'Gbsg Ltd',
#  'True Engineers Limited',
#  'Ricardo Energy & Environment',
#  'Bouygues Uk',
#  'Nhs Wales Shared Services Partnership - Adding Value Through Partnership',
#  'Charged EV',
#  'Premier Engineering',
#  'Jewson',
#  'Sodexo',
#  'Avonside',
#  'Rise Technical Recruitment Ltd',
#  'Hoare Lea',
#  'Dudley College',
#  'Edf Energy',
#  'Phoenix Resourcing Services Ltd',
#  'Unite Students',
#  'Expo Sure USA',
#  'I Love My Job',
#  'Serco',
#  'BP',
#  'Leeds City Council',
#  'Idox Plc',
#  'Morson International',
#  'Information Technology Services',
#  'Better Cotton Initiative',
#  'Saint',
#  'Wild',
#  'Schuh',
#  'Ascential Plc',
#  'University Of Leeds',
#  'Qed Environmental Systems',
#  'Menzies Distribution',
#  'Bilfinger Industrial Services - USA',
#  'London Stock Exchange',
#  'Work Work',
#  'Equinor Uk Limited',
#  'Re&M',
#  'No2h2o LTD',
#  'Nottingham Trent University',
#  'Airbus',
#  'Pentland Group Plc',
#  'Leap Talent Solutions',
#  'Morgan Ryder Associates Limited',
#  'MBDA',
#  'WSP Global',
#  'Finatal',
#  'Network Homes Ltd',
#  'HM Treasury',
#  'Myplanet',
#  'Yorkshire Housing',
#  'Pro-pak Foods',
#  'Nigel Frank',
#  'Jamieson & Clark',
#  'Myenergi',
#  'Startmonday',
#  "King's College London",
#  'Cooper Lomaz',
#  'Roevin',
#  'Comprend',
#  'Starbucks',
#  'Good Energy Group PLC',
#  'Currys Group Limited',
#  'Sgn',
#  'Gabriele Skelton',
#  'Nomura',
#  'Oxfam',
#  'Johnson & Johnson',
#  'H&M',
#  'The University Of Manchester',
#  'Vertas Group Limited',
#  'Belcan',
#  "Queen's University Belfast",
#  'Suez Uk Environment LTD',
#  'Tandridge District Council',
#  'Sophos',
#  'Muddy Boots Software',
#  'News UK & Ireland Limited',
#  'Siemens',
#  'Bennett & Game Recruitment Limited',
#  'KONE Elevators and Escalators',
#  'The Foundation For Education',
#  'Asarum',
#  'Pe Global',
#  'Douglas Scott',
#  'Equilon Enterprises',
#  'Cawood Scientific Ltd.',
#  'KPMG',
#  'Marks Sattin',
#  'Kerry Foods',
#  'Boskalis',
#  'Cyberhawk Innovations',
#  '@Work International',
#  'Technical University Of Denmark',
#  'Viridor Group Limited',
#  'Camdor Global Advisors',
#  'Company News Uk',
#  'Sartorius',
#  'Bramwith Consulting',
#  'Fircroft',
#  'Sure Maintenance',
#  'Westcountry Rivers Trust',
#  'Hayman Mechanical Services Ltd',
#  'Barratt Developments Plc',
#  'Taylor Wimpey',
#  'MillerCoors',
#  'Okta Resourcing',
#  'Sharenergy',
#  'Enappsys',
#  'Natural England',
#  'Mott MacDonald',
#  'Bradford College',
#  'Environment Agency',
#  'Barclay Simpson',
#  'Sillion',
#  'Bath Spa University',
#  'Jaguar Land Rover',
#  'Lancaster University',
#  'SNC-Lavalin',
#  'SRG Europe',
#  'Elevation Recruitment',
#  'Apprenticeships In Scotland',
#  'Domestic & General Group',
#  'Maintenance Heroes Bv',
#  'Knight Frank',
#  'Bangor University',
#  'Opex Selection Limited',
#  'Octopus Investments',
#  'The City Of Edinburgh Council',
#  'Xp Power',
#  'ManpowerGroup',
#  'Lenox Hill Neighborhood House',
#  'Surrey County Council',
#  'The Green Energy Advice Bureau',
#  'Cedar Group',
#  'University College London',
#  'Igloo3 Ltd',
#  'Balfour Beatty',
#  'Hilton Hotels & Resorts',
#  'Nutreco',
#  'Ava Agency Ltd',
#  'Tepeo',
#  'Brakes Group',
#  'Office Depot - Europe',
#  'Airswift',
#  'Kentucky Fried Chicken',
#  'First Ark',
#  '2M Employment Solutions Limited',
#  'Galliford Try International Limited',
#  'Dell Technologies',
#  'Selfridges',
#  'Carrington West',
#  'Derbyshire County Council',
#  'Sumo Services',
#  'Barclays',
#  'Burberry Group',
#  'Capita Resourcing',
#  'Mba Associates',
#  'Telegraph',
#  'Goldman Sachs',
#  'Kingsley Consulting Ltd',
#  'Waters Group',
#  'Fmc Global Talent',
#  'Top Closers',
#  'Grosvenor Group',
#  'University Of Reading',
#  'Kingspan Insulation',
#  'Anglo American',
#  'East Riding Of Yorkshire Council',
#  'Psd Agency',
#  'Eaton Corporation',
#  'Easyjet',
#  'Acre Resources',
#  'Conrad Consulting',
#  'Konker Corporation',
#  'Iccm Us',
#  'Amway',
#  'Cornwall Council',
#  'Aegon',
#  'Reiss',
#  'Cogito Talent Ltd',
#  'Doosan Bobcat',
#  'Highfield Professional Solutions Limited',
#  'Whitbread',
#  'University of Edinburgh',
#  "The Archbishops' Council",
#  'Helec',
#  'Uk Civil Service',
#  'Doctor Care Anywhere',
#  'Limejump Ltd',
#  'South Downs National Park Authority',
#  'Allen Lane',
#  'ENGIE ',
#  'Murphy USA',
#  'Hoare Lea Europe Limited',
#  'Res Agency',
#  'University Of Cambridge',
#  'Daylight Energy',
#  'Eaglecliff',
#  'Caterpillar',
#  'The Barton Partnership',
#  'Entergy',
#  'Pertemps Network',
#  'Joule Hot Water Systems Uk LTD',
#  'Amey plc',
#  'Cundall Group Limited',
#  'Matchtech',
#  'Pledge',
#  'Bardwood Support Services Limited',
#  'University Of Strathclyde',
#  'Jobheron',
#  'NES Fircroft',
#  'Faithful+Gould',
#  'Charlesworth Kennedy',
#  'Resourcing Solutions',
#  'Lombard Odier Investment Managers',
#  'Carbon Trust',
#  'Elemis',
#  'Yo! Sushi',
#  'Ecc Company Ltd.',
#  'Rochdale Boroughwide Housing',
#  'Ross-Shire Engineering',
#  'Wolf & Badger',
#  'Deutsche Post DHL Group',
#  'Babcock International',
#  'Pearson Education',
#  'Tandem Group',
#  'Publicis Groupe',
#  'Gpa Procurement (Uk) Ltd',
#  'The Scottish Salmon Company',
#  'Mrm//Mccann',
#  'Nicholas Associates Group',
#  'Royal Holloway, University Of London',
#  'Immediate Media Co',
#  'National Museums Liverpool',
#  'RWE',
#  'European Metal Recycling Limited',
#  'Vma',
#  'Saica Sl',
#  'Practical Action',
#  'Pda Search & Selection Limited',
#  'Industrial Temps Ltd',
#  'Guardian News & Media',
#  'Met Office',
#  'E - Leather Limited',
#  'Bluetown Online',
#  'Lipton Media',
#  'Pavers',
#  'WestRock',
#  'Nasen',
#  'Santander Bank',
#  'Boc International',
#  'University of Adelaide',
#  'Ipswich Borough Council',
#  'Octopus Energy',
#  "Lloyd's Register Quality Assurance",
#  'Scotlands Rural College',
#  'Hampshire County Council',
#  'Base Group Ltd',
#  'Canadian Solar',
#  'Buckinghamshire Council',
#  'BlackRock',
#  'Clear Edge Search & Selection',
#  'Syngenta Group',
#  'Mde Consultants',
#  'Equals One Ltd',
#  'Spring Technology',
#  'Pexapark (uk) LTD',
#  'The Wildfowl & Wetlands Trust',
#  'Cdi Anderselite',
#  'Petrofac',
#  'Lear Group',
#  'ReliefWeb',
#  'Gaia Technologies Plc',
#  'Creative Mettle',
#  'Society&Co',
#  'Bsi International Group',
#  'Mitie',
#  'Compound Semiconductor Applications Catapult',
#  'Tai Tarian',
#  'University Of South Wales',
#  'The Coca-Cola Company',
#  'North East Lincolnshire Council',
#  'Guidant Group',
#  'Durham University',
#  'Dwr Cymru - Welsh Water',
#  'Bcl Legal',
#  'Oxford Instruments',
#  'Jacobs Engineering Group',
#  'Hilti Great Britain',
#  'Client Server',
#  'Vgc Group',
#  'Wild Berry Associates',
#  'University Of The Arts London',
#  'Xln (Executive Leadership Network)',
#  'Infra-be Group Limited',
#  'Corby Spirit And Wine Limited',
#  'Secanim',
#  'Navartis Ltd',
#  'AstraZeneca',
#  'Great Yarmouth',
#  'Stantec',
#  'People Source Consulting',
#  'Royal Bank Of Scotland',
#  'Homes In Sedgemoor Limited',
#  'Northumbria University',
#  'Vontobel',
#  'Transdev',
#  'Edwards And Co',
#  'Zenzic',
#  'Barclay Meade',
#  'Société Générale Corporate And Investment Banking',
#  'Adecco',
#  'Teledyne Technologies',
#  'Anglian Water Group',
#  'Entrust Social Care LTD',
#  'Tata Steel',
#  'Dawson Levy Resourcing',
#  'Halliday Marx',
#  'Bowman Power Group Ltd',
#  'Chichester District Council',
#  'Coventry University',
#  'May Walters Ltd',
#  'SGS',
#  'University Of East Anglia',
#  'Instant Impact',
#  'Kraft Heinz',
#  'Mettler Toledo',
#  'Lti Metaltech',
#  'Costain Group Plc',
#  'Marcus Webb Associates',
#  'Oleander Law Partners Llp',
#  'Park Royal',
#  'BAE Systems',
#  'Ellen Macarthur Foundation',
#  'Capita Group',
#  'Cirrico',
#  'Government',
#  'The Green Alliance',
#  'Computer Futures',
#  'Tesco',
#  'Virgin Money',
#  'South West Water',
#  'Manchester Metropolitan University',
#  'Crooton',
#  'Haringey Council',
#  'Nps Group',
#  'Powerforce',
#  'Alecto Recruitment',
#  'Smsplc',
#  'Baillie Gifford & Co Limited',
#  'Raeburn Engineering Services (uk) Limited',
#  'Mars Incorporated',
#  'Aaron Wallis Sales Recruitment',
#  'North Lanarkshire Council',
#  'Rhl',
#  'University Of Bristol',
#  'Ashley James',
#  'Wolviston Management Services Limited',
#  'Close Brothers Group PLC',
#  'Corporate Vacancies Sarl',
#  'Tmf Group',
#  'Royal Bank of Canada',
#  'Qinetiq Group PLC',
#  'Tsb Bank',
#  'Financial Services Recruitment',
#  'Quantica Technology',
#  'Wwf',
#  'Seqirus',
#  'Inenco Group',
#  'Syzygy',
#  'Green Deal Energy Advisor LTD',
#  'Accenture',
#  'Fram Search',
#  'Evolution Mining',
#  'So Energy',
#  'Northern Corporation Ltd',
#  'Fife Arms Hotel',
#  'Springboard Success LTD',
#  'Elior Uk',
#  'Thrift Energy Ltd',
#  'Awd Online',
#  'Millbank Holdings Limited',
#  'Raythe Design Solutions',
#  'Harmonic',
#  'University Of Nottingham',
#  'Gasway Services Limited',
#  'Projeq Group',
#  'Drayton Partners Limited',
#  'Accountancy Divisions',
#  'Thames Water',
#  'Rovco',
#  'London School of Economics & Political Science',
#  'Cathcart Energy',
#  'Girling Jones Ltd',
#  'Aura Power Developments LTD',
#  'A.S Technology',
#  'John Wood Group',
#  'Atlas Employment',
#  'Global Counsel',
#  'Biffa',
#  'CBRE',
#  'University Of York',
#  'New Wave Solutions',
#  'McLaren Group',
#  'Goodman Masson',
#  '3Search',
#  'Entain',
#  'Nexus',
#  'Alexander Dennis Limited',
#  'Taylor Hopkinson',
#  'AIA',
#  'Ted Baker',
#  'Vantage Corporate Consulting Limited',
#  'Impact Energy',
#  'Karma Health & Wellbeing Ltd',
#  'Sgs United Kingdom Ltd',
#  'Hyperoptic Ltd.',
#  'Coral',
#  'Continental Girbau',
#  'PIB Group',
#  'Cathcart Associates',
#  'ERSG LTD',
#  'AECOM',
#  'Kingfisher',
#  'Citigroup',
#  'Keepmoat Homes',
#  'Pontoon',
#  'Lampoo',
#  'Mco USA Co',
#  'Heriot-Watt University',
#  'Gärtner Consulting',
#  'Heckfield Place',
#  'Selby Jennings',
#  'Evolution',
#  'Market Intelligence Agency Sarl',
#  'Penspen',
#  "Kellogg's",
#  'Speedy Hire',
#  'Linxon',
#  'Ladbrokes',
#  'Volt',
#  'Scottish And Southern Energy Plc',
#  'Ortolan Group',
#  'Asc Connections',
#  'Persimmon Homes',
#  'Smartsourcing',
#  'National Trust',
#  'Senior Operations',
#  'Atlas Elektronik Uk',
#  'Lantra',
#  'Stirling Warrington',
#  'Thomas Thor Associates Limited',
#  'Sheffield City Council',
#  'Fortil',
#  'Rsk (Uk) Limited',
#  'Morgan Ryder',
#  'University Of Birmingham',
#  'Sian',
#  'Nes It Limited',
#  'The Chinese University Of Hong Kong, Shenzhen 香港中文大学（深圳）',
#  'University Of Lincoln',
#  'Bupa',
#  'Homefield College Limited',
#  'Aggregate Industries Uk',
#  'Man Bites Dog',
#  'University Of Aberdeen',
#  'Investigo Corporation',
#  'Early Years Education',
#  'Renishaw',
#  'Orka Financial Limited',
#  'John Lewis Partnership',
#  'Projective',
#  'Michael Young & Associates',
#  'Wilde & Associates',
#  'University Of Leicester',
#  'Phoenix Group Holdings',
#  'Akton Recruitment',
#  'Boskalis Westminster Ltd.',
#  'Insynth Marketing Ltd',
#  'Netwörx',
#  'Brg',
#  'Renewable Energy South West Plumbing & Heating Services LTD',
#  'Parkinson Gray Associates LTD',
#  'Pandora Jewelry',
#  'A &M Data',
#  'Rssb',
#  'Electrolux',
#  'RGB Exeter',
#  'Swiss Re',
#  'Agro',
#  'MorePeople',
#  'Cranleigh Health & Safety',
#  'Mandeville Retail Limited',
#  'Wallace Hind Selection',
#  'Bwb Consulting Ltd',
#  'Dai Uk',
#  'Party Ingredients Catering Services Limited',
#  'Lyreco',
#  'Wood Mackenzie',
#  'Ukaea LTD',
#  'Bridges',
#  'Imperial College London',
#  'Swarovski',
#  'Davies Veterinary Specialists',
#  'Angela Mortimer U.S.',
#  'Schneider Electric',
#  'Anson Mccade',
#  'Wienerberger Ag',
#  'Frederick James',
#  'Uk Power Networks',
#  'Martin Veasey Talent Solutions',
#  'B&Q',
#  'University Of London',
#  'Pod Point Ltd.',
#  'Macildowie',
#  'Calor Gas Ltd',
#  'University Of Westminster',
#  'Chivas Brothers',
#  'Scottish Government',
#  'Fashion USA',
#  'Calibre Search',
#  'Ball Aerospace',
#  'Elior',
#  'Rubicon Consulting',
#  'Brighton & Hove City Council',
#  'Sds Group',
#  'Chanel',
#  'Uhcw Nhs Trust',
#  'City & County Of Swansea',
#  'Peter Cooks Bread LTD',
#  'Astroscale',
#  'Hotel Chocolat Corporate Ltd',
#  'Afry USA',
#  'British Geological Survey',
#  'Luton Bennett Limited',
#  'Hitachi',
#  'Malcolm Hollis',
#  'Berry Recruitment',
#  'Frazer Jones',
#  'Harnham',
#  'Search Consultancy',
#  'The Scouts Association Of Malaysia / Persekutuan Pengakap Malaysia',
#  'Iberdrola',
#  '1St Executive Ltd',
#  'PepsiCo',
#  'Smurfit Kappa',
#  'Continental',
#  'HSB Technical Services Limited',
#  'Ministry of Defence',
#  'Hanson International Gmbh',
#  'Spie',
#  'Avison Young',
#  'University Of Bath',
#  'Quarriers',
#  'Sevan Multi-Site Solutions',
#  'Nrl Group',
#  'Brindley & Associates',
#  'Legal & General Group Plc',
#  'Five Rivers Environmental Contracting Ltd',
#  'Uwc Atlantic College',
#  'Piper Maddox',
#  'Berkeley Group Holdings Plc',
#  'European Bank For Reconstruction And Development',
#  'The First Uk Bus Pension Scheme Trustee Limited',
#  'Rutherford Cross Limited',
#  'Corre Energy LTD',
#  'The Spencer Academies Trust',
#  'Proud Agency',
#  'DMJ Legal',
#  'Sellick Partnership',
#  'Kloeckner Metals Uk',
#  'Io Associates',
#  'Apex Engineering Solutions',
#  'R & Z Farms',
#  'Ameresco',
#  'Webrecruit',
#  'Amalga Corporation',
#  'Critical Project Resourcing Limited',
#  'Human Capital Solutions',
#  'Field Studies Council',
#  'The James Hutton Institute',
#  'Bristol Energy',
#  "O'Neill & Brennan",
#  'Cwmpas Consulting Limited',
#  'Dma Group',
#  'Smart Hire Ltd',
#  'The Open University',
#  'Hunter Savage',
#  'Energy Saving Trust',
#  'Aatom Recruitment LTD',
#  'Estio Technology Recruitment Limited',
#  'CPI selection',
#  'Jones & Sons',
#  'Irwin & Colton',
#  'Steris Corporation',
#  'Daniels Group',
#  'M&G Investments',
#  'Oceaneering',
#  'Omni Rms',
#  'Wwf-Uk',
#  'Richemont',
#  'DNV',
#  'W5 Resourcing Associates',
#  'Association Of Commonwealth Universities',
#  'Aconex',
#  'Moss Agate Limited',
#  'Emr',
#  'Principal Resourcing',
#  'Constellium Uk Limited',
#  'Cranleigh Scientific',
#  "Laing O'Rourke",
#  'Swansea University',
#  'Brook Street Bureau PLC',
#  'Malmaison Hotels',
#  'A.C.R.E Group',
#  'Tamdown Group Limited',
#  'Aviva',
#  'Fcc Environment',
#  'Scottish Power Limited',
#  'AXA',
#  'The Royal Parks',
#  'Ambassador Theatre Group',
#  'Shawbrook Bank',
#  'University Of Sheffield',
#  'The Natural Environment Research Council',
#  'What Group',
#  'McKinsey',
#  'Adview',
#  'BMW',
#  'AMS',
#  'Alliance Pharma',
#  'Argus Media',
#  'Ds Smith Packaging',
#  'Alexander Mann Solutions',
#  'Kelly Services',
#  'Howden Holdings Limited',
#  'Morgan Mckinley',
#  'Places For People Group Ltd',
#  'Business And Human Rights Resource Centre',
#  'Smart Metering Systems PLC',
#  'Prime',
#  'Allen & York',
#  'Prudential Financial',
#  'Major Players',
#  'LanguageLine Solutions',
#  'Prg Recruitment Llp',
#  'University Of Hertfordshire',
#  'Department For Environment Food & Rural Affairs',
#  'Geoquip Marine Group',
#  'Hunter Selection',
#  'Aramark',
#  'Johnson Matthey',
#  'Lancashire County Council',
#  'Event Concept',
#  'Roche',
#  'Highersteaks',
#  'Willmott Dixon',
#  'Jameson Legal Limited',
#  'GlaxoSmithKline',
#  'Royal National Orthopaedic Hospital',
#  'Rexel Uk Ltd',
#  'Globeleq',
#  'Equityfd & Equityfc &equityinterim',
#  'Subsea 7',
#  'Suez Na',
#  'The Hireworks',
#  'Chadwick Nott',
#  'Virgin Atlantic Airways',
#  'Monmouthshire Building Society',
#  'Ppg Group',
#  'Identify Solutions',
#  'Smarter Utility LTD',
#  'Who',
#  'Experis',
#  'Vallum Associates Limited',
#  "Murray Mcintosh O'Brien",
#  'UiPath',
#  'UL Solutions',
#  'Thermo Fisher Scientific',
#  'Scs Railways',
#  'Planet Mark',
#  "Barnardo's",
#  'Mcs Group',
#  'EMBS',
#  'Opus Energy',
#  'Environmental Justice Foundation',
#  'Coal Authority Building',
#  'British Land',
#  'Diocese Of Salisbury Academy Trust',
#  'Deutsche Windtechnik Ag',
#  'University For The Creative Arts',
#  'JPMorgan Chase',
#  'Ellis It Limited',
#  'Building Careers',
#  'Inverclyde Council',
#  'Frazer-Nash Consultancy',
#  'Premier Group Recruitment',
#  'Loughborough College',
#  'Hendron Pearce Limited',
#  'Capgemini',
#  'Ic Resources',
#  'Amoria Bond',
#  'Newport City Homes',
#  'Code Resources',
#  'Glenelly Infrastructure Solutions Limited',
#  'Cardiff University',
#  'Cms Co. Ltd',
#  'Weatherford International',
#  'Cranfield University',
#  'Gaia Talent',
#  'Ovo Group Ltd',
#  'Charnwood Borough Council',
#  'Wates',
#  'Consulting And Management S.R.L.',
#  'Austin Andrew Ltd',
#  'Executive Resourcing Global Ltd',
#  'British Gas',
#  'PPG Industries',
#  'Tilbury Douglas Construction Limited',
#  'Lioness Consultants',
#  'Arup Group',
#  'Infosys',
#  'Erm Company S.R.O.',
#  'Total Uk Ltd',
#  'Growth[Period]',
#  'Inspire Resourcing Limited',
#  'Foods Connected Ltd',
#  'InfraStructure',
#  'Bruin Corp',
#  'Screwfix',
#  'Urban Star Design',
#  'Chapter Zero',
#  'Nonstop Chemical',
#  'British Heart Foundation',
#  'Rio Tinto',
#  'Transpower Corporation Limited',
#  'Green Software',
#  'Newman Stewart',
#  'Hrs',
#  'Sartorius Stedim Biotech',
#  'Eni',
#  'Office Of Qualifications And Examinations Regulation',
#  'Provide Consulting',
#  'Orstead Eatery',
#  'Fill My Vacancy',
#  'University Of Exeter',
#  'Cleansing Service Group Ltd',
#  'University Of Glasgow',
#  'Jp Engineering',
#  'Carmichael UK',
#  'Bx',
#  'Allegis Global Solutions',
#  'Saint-Gobain',
#  'Risktec Solutions',
#  'Ramboll',
#  'Mt Group Co., Ltd',
#  'Hult International Business School',
#  'Forestry Commission',
#  'Hastings Direct',
#  'Huntress Group',
#  'Senitor Associates',
#  'Expleo Engineering Uk',
#  'Ricardo.At Gmbh',
#  'Lloyds Banking Group',
#  'Biogen',
#  'Cast Uk Limited',
#  'Epping Forest District Council',
#  'Fresca Group Limited',
#  'Cornhouse Consulting',
#  'Ucb Pharma',
#  'Sir Robert Mcalpine',
#  'Eames Consulting',
#  'Hydroplan',
#  'Levi Strauss',
#  'Ceres Power Holdings Plc',
#  'Rytons Associates Ltd',
#  'Ashurst',
#  'Empower Energy',
#  'Scottish Borders Council',
#  'Trinidad Wastewater Plant / Ch2m-jacobs',
#  'Parkside Recruitment',
#  'Leading Co Intl',
#  'Corpus Christi College',
#  'University Of Derby',
#  'JLL',
#  'Laundryheap',
#  'Hasbro',
#  'Sopra Steria Group',
#  'Nuffield Foundation',
#  'Sightsavers',
#  'Volvo',
#  'University Of Liverpool',
#  'Early Years Alliance',
#  'Reach Volunteering',
#  'The University Of Ulster',
#  'Outsource Uk Limited',
#  'First Community Health & Care C.I.C.',
#  'Uk Atomic Energy Authority / Culham Centre For Fusion Energy',
#  'Genesis Agency',
#  'JN Bank Uk LTD',
#  'Badenoch',
#  'Leap29',
#  'Rolls-Royce Holdings',
#  'Totec',
#  'ITR Partners Ltd',
#  'Face2facehr',
#  'Russell Investments',
#  'Glen Dimplex Heating & Ventilation',
#  'Greenwich Partners',
#  'Nine|Twenty',
#  'Kingston Barnes Limited',
#  'Regatta Ltd',
#  'Lime Talent Limited',
#  'Merlin Entertainments Group',
#  'Green Element',
#  'BMT Group LTD',
#  'Arun',
#  'IKEA',
#  'The Hut Group',
#  'Medact',
#  'T. Rowe Price Group',
#  'The One Group',
#  'Wise And Co',
#  'Orion System',
#  'Intertek Testing Services Na',
#  'Premier Resourcing International Limited',
#  'Royal Haskoningdhv',
#  'Bloomberg',
#  'Kp Snacks',
#  'Mag Group',
#  'Vestas',
#  'Big Huge Games',
#  'Ricoh Uk',
#  'Bonnet',
#  'Rullion Group',
#  'Worley',
#  'Colpac Ltd',
#  'Xcellin Ltd',
#  'Aon Hewitt',
#  'Luton Borough Council',
#  'RED',
#  'Blue Heritage, LLC.',
#  'Swale Borough Council',
#  'CRG Tec Limited',
#  'Per (Primary Expedition Research)',
#  'Onezeero',
#  'Be Be Business Services Limited',
#  'Climate17',
#  'The (global) Future Forest Company LTD',
#  'CV Wow',
#  'Vertical Aerospace',
#  'Dms Group',
#  'Morgan Stanley',
#  'Pick Everard',
#  'Greenergy',
#  'Bradford Metropolitan District Council',
#  'Mirai',
#  'Utility People Ltd',
#  'Candidate Source Limited',
#  'A.F. Blakemore & Son Ltd',
#  'Frontiers',
#  'Vivid Resourcing Ltd',
#  'Gatenbysanderson Holdings Limited',
#  'Mid Uk Recycling Ltd',
#  'Talentbloc',
#  'Ecole Polytechnique',
#  'Fawkes & Reece',
#  'Panoramic Care',
#  'Threadneedle Investments Limited',
#  'Alliance Homes Corporation',
#  'Eden Brown',
#  'Hedera Hiring LTD',
#  'Dio',
#  'Nexere Consulting Limited',
#  'Southdowns Environmental Consultants Ltd',
#  'Plymouth University',
#  'Accor',
#  'ITS',
#  'BCD Travel',
#  'Zurich Insurance',
#  'Performance Resourcing Limited',
#  'Harnham Search & Selection',
#  'Advantage Resourcing',
#  'Energy Technical Academy LTD',
#  'Trafford Housing Trust',
#  'The Babraham Institute',
#  'York St John University',
#  'CGI',
#  'KBR',
#  'The Range',
#  'Palladium Group',
#  'Noir',
#  'Fine Organics Limited']

# %%
spec_skills = postings_data['SPECIALIZED_SKILLS_NAME']
comm_skills = postings_data['COMMON_SKILLS_NAME']
sw_skills = postings_data['SOFTWARE_SKILLS_NAME']

# %%
spec_skill_split = [s[4:-2].replace('"', '').split(',\n  ') for s in spec_skills if len(s) > 3 ]
comm_skill_split = [s[4:-2].replace('"', '').split(',\n  ') for s in comm_skills if len(s) > 3 ]
sw_skill_split = [s[4:-2].replace('"', '').split(',\n  ') for s in sw_skills if len(s) > 3 ]

spec_skill_counts = Counter([sk for joblst in spec_skill_split for sk in joblst])
comm_skill_counts = Counter([sk for joblst in comm_skill_split for sk in joblst])
sw_skill_counts = Counter([sk for joblst in sw_skill_split for sk in joblst])

# %%
len(comm_skill_counts), len(spec_skill_counts), len(sw_skill_counts)
# Out:
# (363, 12424, 2162)

# %%
skill_cnt_distr = np.quantile(np.array(list(spec_skill_counts.values())), np.linspace(0,1, 101))

# %%
skill_cnt_distr[25], skill_cnt_distr[50], skill_cnt_distr[99], skill_cnt_distr[99]
# Out:
# (2.0, 5.0, 604.7700000000004, 604.7700000000004)

# %%
plt.semilogx(skill_cnt_distr, np.linspace(0,1, 101))
plt.ylabel('Cumulative distribution')
plt.xlabel('No. of jobs referencing skill')
plt.savefig('Skill_freq.pdf', dpi = 300)

# %%
q95_spec_skills_counts =[(k,w) for k,w in spec_skill_counts.items() if w > 155]
q25_spec_skills_counts =[(k,w) for k,w in spec_skill_counts.items() if w < 3]

# %%
q25_spec_skills_counts
# Out:
# [('Basic Safety Training', 2),
#  ('Intraocular Lenses', 2),
#  ('Risk Selection', 2),
#  ('Next Unit Of Computing (NUC)', 2),
#  ('Voltage Drop', 1),
#  ('Nuclear Design', 1),
#  ('Arc Flash', 1),
#  ('Microsoft Office Live Meeting', 1),
#  ('Bomgar', 1),
#  ('Industrial Networking', 2),
#  ('Craniofacial Surgery', 1),
#  ('Derivative Valuation', 2),
#  ('Software Engineering Process', 2),
#  ('Documentum', 2),
#  ('Computational Mathematics', 2),
#  ('Redmine', 2),
#  ('Cortex M', 1),
#  ('Current Probes', 2),
#  ('International Accounting Standards Board', 2),
#  ('OpenAPI Specification', 1),
#  ('Cloudhub', 2),
#  ('Cloud Security Strategy', 1),
#  ('HP Storageworks', 1),
#  ('Skid Steer Loaders', 2),
#  ('Herbaceous Plants', 1),
#  ('Applications Of Artificial Intelligence', 2),
#  ('Reservoir Modeling', 2),
#  ('MockK', 2),
#  ('Crashlytics', 1),
#  ('Okhttp', 1),
#  ('Near Field Communication', 2),
#  ('Karate (Software)', 2),
#  ('QuerySurge', 1),
#  ('Kinaxis (Software)', 2),
#  ('Supply Chain Collaboration', 1),
#  ('Business Interaction Networks', 1),
#  ('Customer Engagement Planning', 2),
#  ('Developmental History', 1),
#  ('Personalized Medicine', 2),
#  ('Personalized Service', 2),
#  ('USA Patriot Act', 2),
#  ('Surveymonkey', 2),
#  ('Job Safety Analysis', 2),
#  ('Yield Management', 2),
#  ('Java Development Kit', 2),
#  ('Mule (Software)', 1),
#  ('Deployment Project', 2),
#  ('Mvvmcross', 1),
#  ('Audit Defense', 1),
#  ('Tuxedo (Software)', 1),
#  ('Oracle Hyperion Hfm', 1),
#  ('American Standard Code For Information Interchange (ASCII)', 1),
#  ('Capacitive Sensing', 1),
#  ('Balanced Budgeting', 2),
#  ('Octave', 1),
#  ('Aviary', 2),
#  ('Variance Explanation', 2),
#  ('Docking (Computers)', 1),
#  ('Cloud Governance', 1),
#  ('Boundary Layer', 1),
#  ('Supervising Graduate Students', 1),
#  ('Reactive Attachment Disorder', 1),
#  ('Architectural Planning', 2),
#  ('Optimal Inventory Levels', 2),
#  ('Amphibians', 2),
#  ('Google Guice', 2),
#  ('Malnutrition', 2),
#  ('Landing Page Optimization', 1),
#  ('Endovascular Surgery', 2),
#  ('Thoracic Endovascular Aneurysm Repair', 2),
#  ('Adaptive Design', 1),
#  ('Transaxle', 1),
#  ('Oracle Field Service', 2),
#  ('File Service Protocol', 1),
#  ('Online Writing', 2),
#  ('Tally ERP', 1),
#  ('Auscultation', 1),
#  ('Cardiotocography', 1),
#  ('Optical Test Equipment', 2),
#  ('Outside Plant', 2),
#  ('Equinox (OSGi)', 2),
#  ('Disaster Planning', 1),
#  ('Fluid Simulation', 1),
#  ('Particle Systems', 2),
#  ('FumeFX', 2),
#  ('HVAC Estimating', 2),
#  ('Microsoft Dynamics ERP', 2),
#  ('ISO 14064', 2),
#  ('Yoast', 2),
#  ('Analyst Relations', 2),
#  ('Wafer Fabrication', 2),
#  ('Graphic Novel', 1),
#  ('Extensible Authentication Protocol', 2),
#  ('Cruisecontrol.net', 1),
#  ('Risk Management Information Systems', 2),
#  ('Link Analysis', 1),
#  ('Expense Account', 1),
#  ('Educational Games', 1),
#  ('Adobe InCopy', 2),
#  ('Share Permissions', 1),
#  ('Dental Instruments', 2),
#  ('Active Treatment', 2),
#  ('Spa Management', 2),
#  ('Dalvik', 2),
#  ('Conformance Testing', 2),
#  ('Hibernate Query Language', 2),
#  ('Adjusting Entries', 1),
#  ('QuoteWerks', 1),
#  ('Command Prompt', 1),
#  ('MSBuild', 2),
#  ('Dynamic Programming', 2),
#  ('Path Analysis', 2),
#  ('Compression Fitting', 1),
#  ('Architecture Analysis', 2),
#  ('Phone Screening', 2),
#  ('Apttus', 2),
#  ('Highway Materials', 1),
#  ('Vertical Alignment', 1),
#  ('DLX', 1),
#  ('Environmental Contamination', 2),
#  ('Crystallization', 1),
#  ('Condensed Matter', 2),
#  ('Chemical Physics', 2),
#  ('Soft Matter', 2),
#  ('StumbleUpon', 1),
#  ('Bioconductor (Bioinformatics Software)', 2),
#  ('Quantum Imaging', 1),
#  ('Non-Invasive Procedures', 2),
#  ('Self-Contained Breathing Apparatus', 1),
#  ('Engraving', 1),
#  ('User Identification', 2),
#  ('Hardware Security Module', 2),
#  ('Application Delivery Controller', 2),
#  ('Body Work', 1),
#  ('Vegetation Surveys', 1),
#  ('Oxygen Cylinders', 1),
#  ('Character Animation', 2),
#  ('Boring Mill', 1),
#  ('Voltmeter', 2),
#  ('Application Streaming', 1),
#  ('Application Virtualization', 2),
#  ('White Space Analysis', 1),
#  ('Biofeedback', 1),
#  ('Padrino (Web Framework)', 1),
#  ('Genomic Testing', 2),
#  ('Dell PowerVault', 1),
#  ('Monoliths', 2),
#  ('Ceramic Engineering', 1),
#  ('Multimedia Messaging Services', 2),
#  ('Cell Broadcast', 1),
#  ('Code Snippets', 1),
#  ('Electrosurgical Devices', 2),
#  ('Copy Testing', 2),
#  ('Sisense', 2),
#  ('Congenital Defects', 2),
#  ('Electric Bass Guitars', 2),
#  ('JBoss EAP', 2),
#  ('Electronic Referrals', 2),
#  ('Code Complexity', 1),
#  ('Farm Property', 1),
#  ('Emissions Trading', 2),
#  ('Music Libraries', 2),
#  ('Sexually Transmitted Diseases', 2),
#  ('Load Securement', 1),
#  ('Tracking Stock', 1),
#  ('Good Language Learner Studies', 1),
#  ('Java Scripting Languages', 2),
#  ('International Standard Text Codes', 1),
#  ('Data Binding', 2),
#  ('Google Cloud Composer', 2),
#  ('Master Boot Records', 1),
#  ('Integrated Workplace Management Systems', 1),
#  ('Admissions Operations', 1),
#  ('3rd Party Systems Integration', 1),
#  ('Revenue Enhancement', 1),
#  ('Darkroom', 2),
#  ('Ceramic Art', 2),
#  ('Inverse Kinematics', 1),
#  ('Primefaces', 1),
#  ('Return Merchandise Authorization', 1),
#  ('Video Marketing', 2),
#  ('Commercial Paper', 2),
#  ('National Response Framework', 2),
#  ('Issuer', 2),
#  ('Tender Offer', 1),
#  ('Stripe Connect', 1),
#  ('Database Upgrades', 2),
#  ('Employee Newsletters', 1),
#  ('Vehicle Remarketing', 2),
#  ('Extensible Messaging And Presence Protocol (XMPP)', 2),
#  ('Google Photos', 1),
#  ('Polypectomy', 1),
#  ('Healthcare Delivery Models', 1),
#  ('Common Technical Document', 1),
#  ('Modern Art', 1),
#  ('Contemporary Art', 1),
#  ('Therapeutic Hypothermia', 1),
#  ('In Situ Hybridization', 2),
#  ('Softphone', 2),
#  ('Soft Soldering', 1),
#  ('Demographic Analysis', 1),
#  ('Descriptive Statistics', 2),
#  ('Gasification', 2),
#  ('Laser Diode', 1),
#  ('Photographic Printing', 1),
#  ('Comb Binding', 1),
#  ('Chi-Squared Tests', 1),
#  ('Card Sorting', 2),
#  ('Nutraceuticals', 1),
#  ('JIRA Studio', 1),
#  ('Biochemical Techniques', 2),
#  ('Environmental Pollutants', 1),
#  ('Cell Physiology', 1),
#  ('Product Data Hub', 2),
#  ('Media Negotiations', 1),
#  ('Trade Promotion Management', 2),
#  ('Medical Record Management', 2),
#  ('IWork', 2),
#  ('Small Computer System Interface (SCSI)', 2),
#  ('Quadratic Programming', 1),
#  ('Integer Programming', 2),
#  ('Data Caching', 1),
#  ('Gurobi', 1),
#  ('IBM ILOG CPLEX Optimization Studio (CPLEX)', 1),
#  ('IdentityServer4', 1),
#  ('Code Comments', 2),
#  ('Automated Recruitment', 1),
#  ('Resistors', 2),
#  ('Comparable Transactions', 2),
#  ('Guidewire Core', 2),
#  ('TortoiseSVN', 2),
#  ('Gosu (Programming Language)', 2),
#  ('Newspaper Design', 1),
#  ('OpenCart', 1),
#  ('Automatic Call Distributor', 2),
#  ('Apgar Score', 1),
#  ('Managed Markets', 1),
#  ('Evidence Analysis', 2),
#  ('Blood Product Administration', 2),
#  ('IronPort', 1),
#  ('Serverless Security', 2),
#  ('Bore Gauges', 1),
#  ('Rust Removal', 1),
#  ('Supply Transport', 1),
#  ('Information Framework', 1),
#  ('App Data', 1),
#  ('Wireless Application Protocol (WAP)', 2),
#  ('Supercritical Fluid', 1),
#  ('Noise Reduction', 1),
#  ('Ethical Research', 1),
#  ('Combined Sewer', 1),
#  ('Non-Volatile Memory', 1),
#  ('Memory Module', 1),
#  ('Mixpanel', 2),
#  ('Graphical User Interface Testing', 1),
#  ('Mining Engineering', 2),
#  ('Medical Intensive Care Unit', 1),
#  ('Core Drills', 1),
#  ('NESTA', 2),
#  ('RTLinux', 1),
#  ('Multi-Core Processors', 1),
#  ('Java Web Services', 2),
#  ('IBM Worklight', 1),
#  ('Medical Surveillance', 2),
#  ('GIF Animation', 1),
#  ('Package Development Process', 2),
#  ('Trapeze (Software)', 1),
#  ('Motor Soft Starter', 1),
#  ('Pandemic Readiness', 1),
#  ('Social Interventionism', 1),
#  ('Swim Coaching', 1),
#  ('Business Education', 2),
#  ('Logic Synthesis', 2),
#  ('Monte Carlo Methods', 2),
#  ('Visual Simulations', 1),
#  ('Dassault Syst Mes DELMIA (Software)', 1),
#  ('Petroleum Industry', 2),
#  ('Sun ONE', 1),
#  ('GoToWebinar', 2),
#  ('AIOps (Artificial Intelligence For IT Operations)', 2),
#  ('Alation Data Catalog', 2),
#  ('Omnis Studio', 2),
#  ('Cutting Wood', 1),
#  ('Electronic Symbols', 1),
#  ('Test Automation Management Tools', 2),
#  ('Backhoes', 2),
#  ('Legal Electronic Data Exchange Standard', 2),
#  ('Cross-Functional Project Management', 2),
#  ('Usage Tracking', 1),
#  ('Sustainable Remediation', 1),
#  ('Wound Healing', 1),
#  ('VDA 6.1 Standard', 2),
#  ('Aircraft Assembly', 2),
#  ('Sustainable Infrastructure', 2),
#  ('Native Code', 2),
#  ('Variable Frequency Drives', 2),
#  ('Backwards Compatibility', 2),
#  ('Mobile Architecture', 2),
#  ('GIAC Intrusion Prevention', 2),
#  ('Financial Industry Regulatory Authorities', 2),
#  ('Categorical Data', 1),
#  ('Sample Size Determination', 1),
#  ('Statistical Theory', 1),
#  ('Analysis Of Variance (ANOVA)', 2),
#  ('Parametric Methods', 1),
#  ('All Terrain Vehicles', 2),
#  ('Water Pipes', 1),
#  ('MRO Software', 2),
#  ('Document Conversion', 1),
#  ('Language Model', 1),
#  ('IBM Resource Access Control Facility', 2),
#  ('Proxy Networks', 1),
#  ('Powertrain Control Module', 1),
#  ('Environmental Due Diligence', 1),
#  ('Katalon Studio', 1),
#  ('Orbital Welding', 1),
#  ('Coolants', 1),
#  ('ManageEngine AssetExplorer', 1),
#  ('JMockit', 1),
#  ('CruiseControl', 2),
#  ('Demand Modeling', 1),
#  ('Vulcanization', 1),
#  ('Sustainable Materials', 1),
#  ('Regenerative Design', 1),
#  ('Artificial Intelligence Systems', 1),
#  ('JavaScript Build', 1),
#  ('MERN Stack', 1),
#  ('Statistical Thinking', 2),
#  ('NetBase Quid', 2),
#  ('Audio Codecs', 1),
#  ('Liferay', 2),
#  ('Prior Art', 1),
#  ('AWS CLI (Command Line Interface)', 2),
#  ('Java Object Oriented Querying', 1),
#  ('Shrubbery', 2),
#  ('GoSystems (Tax Software)', 1),
#  ('Osteoarthritis', 1),
#  ('Adobe Digital Editions', 1),
#  ('Political Ecology', 1),
#  ('PSD Files', 1),
#  ('Web Typography', 1),
#  ('Hypertrophy', 2),
#  ('Percutaneous Procedures', 2),
#  ('Patent Foramen Ovale', 1),
#  ('Valvuloplasty', 1),
#  ('Coronary Catheterization', 1),
#  ('Swivel', 1),
#  ('Ansi Sql', 2),
#  ('Endovascular Aneurysm Repair', 1),
#  ('Micro Focus Performance Center', 1),
#  ('Digital Subscriber Line', 2),
#  ('Internet Radio', 1),
#  ('Bioarchaeology', 1),
#  ('Skybox', 2),
#  ('Managed Code', 1),
#  ('Space Environment', 2),
#  ('Legal Writs', 2),
#  ('Vendor-Managed Inventory', 2),
#  ('New Product Information', 2),
#  ('Social Entrepreneurship', 2),
#  ('Shipping Regulations', 2),
#  ('Family Planning', 1),
#  ('Patient Interviews', 2),
#  ('Project Method', 1),
#  ('Execution Time', 1),
#  ('Contamination Control', 2),
#  ('Buildbot', 1),
#  ('Social Network Analysis', 2),
#  ('AdWorks', 1),
#  ('Desktop Publishing', 2),
#  ('Cross-Functional Coordination', 2),
#  ('Healthcare Reforms', 1),
#  ('Manufacturing Resource Planning', 2),
#  ('Low-Income Housing Tax Credit', 1),
#  ('OpenLink Endur (Software)', 2),
#  ('Culinary Science', 1),
#  ('Steam Sterilization', 2),
#  ('Advanced Traffic Management Systems', 2),
#  ('ESS/MSS', 2),
#  ('Interactive System Productivity Facility (ISPF)', 1),
#  ('System Display And Search Facility (SDSF)', 1),
#  ('Rexx (Programming Language)', 2),
#  ('Squid (Proxy Server)', 2),
#  ('Oracle Responsys (Marketing Software)', 2),
#  ('Adaptive Equipment', 2),
#  ('Bradycardia', 2),
#  ('Arterial Catheter', 1),
#  ('Google Desktops', 1),
#  ('End Mill', 2),
#  ('HP/OpenText Exstream', 1),
#  ('Data Terminal Equipment', 2),
#  ('Codeception', 1),
#  ('Professional Speaking', 2),
#  ('Nuchal Scan', 1),
#  ('IdentityIQ', 1),
#  ('Enhanced Data Rates For GSM Evolution', 2),
#  ('Network Intelligence', 2),
#  ('Volumetric-Modulated Arc Therapy (VMAT)', 2),
#  ('External Fixation', 1),
#  ('Google Alerts', 1),
#  ('Mathematical Physics', 1),
#  ('Particle Physics Experiments', 2),
#  ('Electronic Funds Transfer', 2),
#  ('Origami', 1),
#  ('Freeze Dryers', 2),
#  ('Political Economy', 1),
#  ('Pyrolysis', 2),
#  ('Critical Incident Stress Management', 1),
#  ('Radiochemistry', 1),
#  ('Mechanical Tools', 1),
#  ('Agricultural Policy', 2),
#  ('Air Cargos', 1),
#  ('Cargo Handling', 2),
#  ('Cargo Loading', 1),
#  ('Labor Legislation', 2),
#  ('Texas Instruments TMS320', 2),
#  ('Ecological Services', 2),
#  ('Theodolite', 2),
#  ('High-Speed Downlink Packet Access', 1),
#  ('Dual Mode Mobile', 1),
#  ('Coordinate Systems', 2),
#  ('Controlled Experiments', 2),
#  ('EViews', 2),
#  ('Legal Writing', 1),
#  ('Multicast Source Discovery Protocol', 2),
#  ('Continuing Legal Education', 2),
#  ('Chemical Injection Systems', 2),
#  ('Voltage Regulation', 1),
#  ('Air Distribution Systems', 1),
#  ('Enhanced Oil Recovery (EOR)', 1),
#  ('Hydronics', 1),
#  ('Final Drawings', 1),
#  ('Ventilation Fans', 1),
#  ('Powerpivot', 2),
#  ('Microinjection', 2),
#  ('Arthropods', 2),
#  ('Cyberknife', 1),
#  ('Six Degrees Of Freedom', 2),
#  ('Dosimetry', 2),
#  ('Forestry Equipment', 1),
#  ('Air Separation', 1),
#  ('H.323 Protocol', 2),
#  ('Travel Cost Analysis', 2),
#  ('Low Carbon Solutions', 2),
#  ('Polarization', 1),
#  ('Gel Filtration Chromatography', 2),
#  ('Commercial Transaction', 1),
#  ('Cyber Warfare', 1),
#  ('Access Control Matrix', 1),
#  ('Control Loops', 2),
#  ('Empirical Process', 1),
#  ('Electron Optics', 1),
#  ('Cloud Collaboration', 1),
#  ('Financial Project Management', 1),
#  ('Traffic Signal Design', 2),
#  ('Adaptive Control', 2),
#  ('Vimeo', 1),
#  ('Flickr', 2),
#  ('Theatre Production', 2),
#  ('Seismology', 2),
#  ('Bentley AutoPIPE', 2),
#  ('Pipe Stress Engineering', 2),
#  ('Microsoft Framework', 2),
#  ('eTapestry (Fundraising Software)', 2),
#  ('Ride Height', 1),
#  ('Sustainable Agriculture', 1),
#  ('Rural Development', 2),
#  ('Plant Breeding', 1),
#  ('Failover Testing', 1),
#  ('Health Systems', 2),
#  ('Burnishing', 1),
#  ('Apache MXNet', 2),
#  ('GNU Image Manipulation Program (GIMP)', 2),
#  ('Small Business Software', 1),
#  ('Ifttt', 2),
#  ('Thinkific', 1),
#  ('Zapier', 2),
#  ('VMWare NSX-T', 1),
#  ('Clinical Messaging', 2),
#  ('Climate Information', 1),
#  ('Cloud Management Platforms', 2),
#  ('Air Sampling', 1),
#  ('Airflow', 2),
#  ('Oracle Applications DBA', 1),
#  ('Open Access', 1),
#  ('Program Standards', 2),
#  ('Chronic Care', 2),
#  ('Methadone', 2),
#  ('Copayment Collection And Processing', 2),
#  ('Buprenorphine', 1),
#  ('Constitutional Documents', 2),
#  ('Mincing', 1),
#  ('Oracle SOA Suite', 2),
#  ('User Analysis', 1),
#  ('IBM Business Process Manager (BPM)', 1),
#  ('Korn Shell', 2),
#  ('Technology Life Cycle', 2),
#  ('IBM SAN Volume Controllers', 1),
#  ('Traefik', 1),
#  ('Wire Cutters', 1),
#  ('Forensic Chemistry', 1),
#  ('Dormer', 2),
#  ('Code Enforcement', 1),
#  ('Solar Development', 2),
#  ('Empirical Analysis', 1),
#  ('Fixatives', 1),
#  ('Retrospective Reviews', 1),
#  ('Icon Design', 1),
#  ('Glass Cutters', 2),
#  ('Immunohematology', 2),
#  ('Double Taxation', 1),
#  ('Investment Control', 2),
#  ('Plastics Engineering', 1),
#  ('Macola (ERP Software)', 1),
#  ('Decorative Arts', 1),
#  ('Museum Studies', 1),
#  ('Advance Steel (CAD Software)', 2),
#  ('Operational Support And Analysis', 2),
#  ('Distributed Programming', 1),
#  ('Mechanization', 1),
#  ('S1000D Specification', 2),
#  ('Reference Application', 2),
#  ('LS-DYNA (FEA Software)', 1),
#  ('Profit And Loss Forecasting', 1),
#  ('Business Model Innovation', 1),
#  ('News Anchoring', 1),
#  ('JetBrains IDE', 2),
#  ('Devtools', 1),
#  ('Gift Wrapping', 1),
#  ('Stage Lighting', 1),
#  ('Sungard', 2),
#  ('VPN Tunnels', 2),
#  ('Compressor Station', 2),
#  ('Accounting Machines', 1),
#  ('Shallow Foundation', 1),
#  ('Assembly Modelling', 1),
#  ('Flow Chemistry', 2),
#  ('Publish Subscribe', 2),
#  ('Automotive Engines', 1),
#  ('Metadata Standards', 1),
#  ('Machine Code', 2),
#  ('Squeegee', 2),
#  ('Equal Credit Opportunity Act', 2),
#  ('Disruptive Innovation', 1),
#  ('Big Ip', 1),
#  ('SSL Acceleration', 1),
#  ('Flexible Type', 1),
#  ('Semen Collection', 1),
#  ('ModeliCA', 1),
#  ('Jenkinsfile', 2),
#  ('Multi Router Traffic Grapher', 1),
#  ('Hormone Replacement Therapy', 1),
#  ('Transmission System Operator', 1),
#  ('Statement On Auditing Standards (SAS) No. 70', 1),
#  ('Horizontal Milling', 2),
#  ('Video Capture', 2),
#  ('Event Bus', 1),
#  ('Bokeh', 2),
#  ('Higher-Order Thinking', 2),
#  ('Bag-Valve Mask Resuscitation', 1),
#  ('Functional Interface', 2),
#  ('Ligand Binding Assay', 1),
#  ('Spectrum Management', 2),
#  ('Industrial Dishwashers', 2),
#  ('Serbo-Croatian Language', 2),
#  ('Immunophenotyping', 2),
#  ('Cell Sorting', 1),
#  ('Cloning (Biology)', 1),
#  ('Maternal-Fetal Medicine', 1),
#  ('Geojson', 2),
#  ('Mobile Network Operator', 2),
#  ('HP Servers', 2),
#  ('Laser Design', 1),
#  ('Electro-Optical Systems', 1),
#  ('Textile Machinery', 1),
#  ('Precision Mechanics', 1),
#  ('Microfluidics', 2),
#  ('Primary Education', 2),
#  ('Family Studies', 1),
#  ('Guest Ledgers', 1),
#  ('Sleep Medicine', 2),
#  ('Liquidity Forecasting', 2),
#  ('Advertising Copywriting', 2),
#  ('Cashless Catering', 1),
#  ('Horticultural Therapy', 1),
#  ('Archival Management', 2),
#  ('Accounting For Income Taxes', 2),
#  ('Economic Planning', 1),
#  ('Weld Quality Assurance', 1),
#  ('Vert.x', 2),
#  ('Adult Development', 1),
#  ('Food Law', 2),
#  ('Rheumatoid Arthritis', 2),
#  ('Financial Economics', 1),
#  ('Fair Credit Reporting Act', 2),
#  ('PrestaShop', 1),
#  ('Flame Cutting', 1),
#  ('Packeteer', 2),
#  ('Tier 3 Technical Support', 2),
#  ('AutoIt', 1),
#  ('Value-Based Care', 1),
#  ('Oracle Agile', 2),
#  ('Space Weather', 1),
#  ('Space Radiation', 1),
#  ('Cppunit', 2),
#  ('Testcomplete', 2),
#  ('Refractive Index', 1),
#  ('Xunit.net', 1),
#  ('Infragistics', 1),
#  ('Basic Fire Fighting', 1),
#  ('Mplus (Structural Equation Modeling)', 1),
#  ('Network Encryption', 1),
#  ('Beadwork', 2),
#  ('Urban Forestry', 1),
#  ('Style Sheets', 1),
#  ('Contract Lifecycle Management', 2),
#  ('Resource Consumption Accounting', 1),
#  ('Reading Intervention', 2),
#  ('Housing Policy', 1),
#  ('Radioactive Contamination', 1),
#  ('Health Physics', 1),
#  ('Juvenile Justice', 1),
#  ('Factiva', 1),
#  ('SAP IS Retail', 2),
#  ('Live Cell Imaging', 2),
#  ('EPIC software', 1),
#  ('Episiotomy', 2),
#  ('Dystocia', 1),
#  ('Chemical Peels', 1),
#  ('Visual Marketing', 2),
#  ('Antivirals', 2),
#  ('Unmanned Aerial Vehicle', 2),
#  ('Charles Proxy', 2),
#  ('Flying Qualities', 2),
#  ('Aerodynamic Heating', 1),
#  ('College Recruitment', 2),
#  ('HotSOS (Hotel Software)', 1),
#  ('Microwave Chemistry', 1),
#  ('Digital Audio Workstation', 1),
#  ('Music Software', 1),
#  ('Security Studies', 2),
#  ('Military Doctrine', 1),
#  ('Linear Programming', 1),
#  ('AKTA (Chromatography Technology)', 2),
#  ('Size-Exclusion Chromatography', 2),
#  ('Auditory Processing', 1),
#  ('Cognitive Processing', 2),
#  ('Electrical Rule Check', 2),
#  ('Protocol Analyzer', 1),
#  ('Stubbing', 2),
#  ('Patient Transfer Equipment', 2),
#  ('C++/CLI', 1),
#  ('Occupational Hearing Conservation', 2),
#  ('Medical Direction', 2),
#  ('Preventive Healthcare', 2),
#  ('Chemical Weapon', 1),
#  ('Rotary Screw Compressor', 1),
#  ('Greenplum', 1),
#  ('Audio Mixing', 2),
#  ('Overhead Hoists', 2),
#  ('Behat', 2),
#  ('Eye Examination', 1),
#  ('Advanced Robotics', 2),
#  ('Food Waste Management', 2),
#  ('Structural Systems', 2),
#  ('Google Webmaster Tools', 1),
#  ('Flexographic Printing Press Operation', 2),
#  ('Sleep-Disordered Breathing', 1),
#  ('Facebook Platform', 1),
#  ('Employee Research', 2),
#  ('Industrial Management', 2),
#  ('Geospatial Data Abstraction Library (GDAL)', 2),
#  ('Arcpy', 2),
#  ('Construction Materials Testing', 1),
#  ('Java Architectures', 1),
#  ('AWS Amplify', 2),
#  ('Project Flows', 1),
#  ('Secure FTP (Software)', 1),
#  ('Assortment Optimization', 2),
#  ('Electronic Oscillator', 2),
#  ('Target Platform', 2),
#  ('Enscape (VR Rendering Software)', 2),
#  ('Oracle Configure-Price-Quote (CPQ)', 2),
#  ('Oracle Receivables', 1),
#  ('Options Strategies', 2),
#  ('Event Management Software', 2),
#  ('PhRMA Code', 1),
#  ('Intrusion Prevention Systems', 2),
#  ('Microsoft OneDrive', 1),
#  ('Perm (Hairstyle)', 1),
#  ('Pediatric Surgery', 2),
#  ('Magnetic Particle Inspections', 2),
#  ('Theoretical Chemistry', 2),
#  ('Generator Installation', 1),
#  ('RStudio', 2),
#  ('Commercial Insurances', 2),
#  ('Early Phase Development', 1),
#  ('Habitat Assessment', 1),
#  ('Industrial Security', 1),
#  ('Elementary Matrix (Linear Algebra)', 2),
#  ('Peak Expiratory Flow', 2),
#  ('Sequential Access', 1),
#  ('Denormalization', 1),
#  ('Spark Core', 1),
#  ('Stromal Cell', 1),
#  ('Substance Abuse Assessments', 2),
#  ('Engineering Procurement And Construction Management', 2),
#  ('Graining', 1),
#  ('Public Health Laws', 1),
#  ('OpenEdge Advanced Business Language', 2),
#  ('Microsoft Family Safety', 1),
#  ('Tabular Data', 1),
#  ('Reverse Proxy', 1),
#  ('Application Notes', 2),
#  ('Corporate Accounts Payable', 1),
#  ('OrientDB', 1),
#  ('Disease Control', 1),
#  ('Opening Statement', 2),
#  ('PostCSS', 2),
#  ('Educational Therapy', 1),
#  ('External Storage', 2),
#  ('PEST Analysis', 1),
#  ('Medisoft', 1),
#  ('Carpet Maintenance', 1),
#  ('Refurbishing', 2),
#  ('Interactive Web Pages', 1),
#  ('Ovarian Cancer', 1),
#  ('FatWire', 1),
#  ('Content Pages', 1),
#  ('Acquisition Due Diligence', 1),
#  ('IP Pbx', 2),
#  ('Microsoft DNS', 1),
#  ('Cisco Systems VPN Client', 1),
#  ('Chemistry Education', 1),
#  ('Brand Style Guides', 1),
#  ('Foundation Engineering', 1),
#  ('GoToAssist', 1),
#  ('System Center Virtual Machine Management', 2),
#  ('Enterprise Services Repository', 1),
#  ('Vapor Recovery', 1),
#  ('Ellipse', 1),
#  ('Merchant Account', 1),
#  ('Migration Testing', 2),
#  ('Data Structure Alignment', 2),
#  ('Endurance Training', 1),
#  ('Urban Sustainability', 1),
#  ('Software-Defined Data Center', 1),
#  ('Selective Soldering', 1),
#  ('Borland C++ (Borland Software)', 1),
#  ('Grounding Systems', 2),
#  ('Workplace Wellness', 2),
#  ('Animal Observation And Monitoring', 1),
#  ('Data Comparison', 1),
#  ('Cardiac Valve Replacement', 1),
#  ('Ingredient Measurement', 2),
#  ('Visual Paradigm For UML', 1),
#  ('Public Works', 1),
#  ('Water Quality Modeling', 1),
#  ('Variable-Length Subnet Masking (VLSM)', 1),
#  ('Pressure Drops', 2),
#  ('Acoustic Doppler Current Profiler', 1),
#  ('Electron Energy Loss Spectroscopy', 1),
#  ('Spawning', 1),
#  ('Academic Libraries', 2),
#  ('Variable Rules Analysis', 2),
#  ('Casting Design', 2),
#  ('Embedded SQL', 1),
#  ('METAR', 2),
#  ('Domo', 2),
#  ('Wire Transfer', 2),
#  ('Turnkey (Business)', 2),
#  ('Hydrogen Sulfide (H2S) Training', 1),
#  ('Ability To Distinguish Colors', 2),
#  ('Digital Filter', 1),
#  ('Block Design', 1),
#  ('Gateway Load Balancing Protocols', 2),
#  ('Open Neural Network Exchange (ONNX)', 1),
#  ('Java Runtime Environment', 1),
#  ('Promotional Effectiveness', 2),
#  ('Fixed Assets Management', 1),
#  ('DNA Repair', 2),
#  ('Survivability', 2),
#  ('Monoclonal Antibody Production', 1),
#  ('Air Brakes', 1),
#  ('Health Crisis', 2),
#  ('Alamofire', 1),
#  ('Attenuation', 2),
#  ('Vericut', 1),
#  ('Testflight', 1),
#  ('Red Hat Satellite', 2),
#  ('Consumer Debt', 2),
#  ('Graphics Processing Unit (GPU)', 1),
#  ('Aircraft Technology', 1),
#  ('Generic Buffer Management', 2),
#  ('Twitter Advertising', 1),
#  ('Archival Research', 1),
#  ('Closed Loop', 2),
#  ('Synology', 2),
#  ('ISO 19011 Standard', 1),
#  ('Histogram', 1),
#  ('Liver Biopsies', 1),
#  ('Travel Insurance', 1),
#  ('Dermabrasion', 2),
#  ('Archive File', 1),
#  ('Physical Schema', 1),
#  ('Forced Draft Systems', 1),
#  ('XML For Analysis', 1),
#  ('Merchandise Planning', 1),
#  ('Battle Rhythm', 1),
#  ('Information Ordering', 1),
#  ('Essential Oils', 1),
#  ('Quantum Information Sciences', 2),
#  ('Dividend Calculations', 1),
#  ('Dance Education', 2),
#  ('Web Property', 1),
#  ('Paramics (Traffic Simulation Software)', 2),
#  ('Dissociation', 1),
#  ('Cellular Differentiation', 1),
#  ('SMT Placement Equipment', 1),
#  ('Automated Optical Inspection', 2),
#  ('Wave Soldering', 1),
#  ('Toy Industry', 2),
#  ('Middle Eastern Studies', 2),
#  ('Abiotic Stress Resistance', 1),
#  ('Artificial Insemination', 1),
#  ('Oracle VM Server For SPARC', 1),
#  ('Aircraft Leasing', 1),
#  ('Aircraft Records', 2),
#  ('Business Activity Monitoring', 2),
#  ('Demographic Transition', 2),
#  ('Computer-Mediated Communication', 1),
#  ('NVivo', 2),
#  ('Sludge', 2),
#  ('Template Metaprogramming', 1),
#  ('Game Physics', 1),
#  ('Molecular Pathology', 1),
#  ('Professional Liability', 2),
#  ('Website Monitoring', 1),
#  ('Web Search Query', 1),
#  ('Photochemistry', 2),
#  ('Electronic Logbook', 2),
#  ('Playwright (Software Testing)', 1),
#  ('Business Diversification', 1),
#  ('News Analysis', 2),
#  ('FedRAMP', 1),
#  ('Medical Records Release', 2),
#  ('Database Audit', 1),
#  ('Oracle Exadata', 2),
#  ('Oracle GoldenGate', 2),
#  ('Circuit Switches', 1),
#  ('Youth Health', 2),
#  ('Crime Reports', 2),
#  ('Plastic Welding', 1),
#  ('Survey Methodologies', 1),
#  ('Concentrix Solar', 2),
#  ('Contamination', 1),
#  ('Motivational Speaking', 2),
#  ('Hard Disk Drives', 1),
#  ('Apache Avro', 2),
#  ('SPARQL Protocol And RDF Query Language (SPARQL)', 2),
#  ('Apache Thrift', 2),
#  ('Environmental Data Analysis', 2),
#  ('Payer Marketing', 2),
#  ('Wrongful Dismissal', 1),
#  ('Contract Auditing', 2),
#  ('Ivalua (Spend Management Software)', 2),
#  ('IBM WebSphere Portal', 1),
#  ('Investment Account Management', 1),
#  ('Metabolic Diseases And Disorders', 2),
#  ('Yandex', 1),
#  ('Office Open XML', 1),
#  ('Pistons', 1),
#  ('Air-Cooled Engines', 2),
#  ('Liners', 1),
#  ('Connecting Rods', 1),
#  ('Gas Turbine', 2),
#  ('Needs Based Selling', 2),
#  ('Live Migration', 1),
#  ('Game Theory', 2),
#  ('Feature Learning', 1),
#  ('Cable Television', 1),
#  ('Retinopathy', 2),
#  ('Squarespace', 2),
#  ('Linux-Powered Devices', 1),
#  ('Socket Programming', 1),
#  ('Heavy Equipment Transporter System', 1),
#  ('Laser Doppler Vibrometer', 2),
#  ('Popular Education', 1),
#  ('Prostate Biopsies', 1),
#  ('Cryo-Electron Microscopy', 2),
#  ('Biological Process', 2),
#  ('SIMD', 2),
#  ('Supervised Learning', 1),
#  ('Assortment Planning', 2),
#  ('Turbine Blade (Engines)', 2),
#  ('Primer Design', 2),
#  ('Apex Code', 1),
#  ('Liquidnet', 2),
#  ('Credit Default Swap', 2),
#  ('Capital IQ (Software)', 2),
#  ('Electronic Communication Networks', 1),
#  ('Flux Analysis', 1),
#  ('Prescription Drug Marketing Act', 2),
#  ('Deep Vein Thrombosis', 2),
#  ('Crankshaft', 1),
#  ('Engineering Change Packages', 1),
#  ('Object-Relational Database', 1),
#  ("Prosecutor's Management Information System", 1),
#  ('Pavement Engineering', 2),
#  ('Google Optimize', 2),
#  ('Microsoft Enterprise Project Management', 2),
#  ('Parasitology', 2),
#  ('Personalized Marketing', 1),
#  ('Concur Travel', 2),
#  ('Craft Service', 1),
#  ('Network Packet', 2),
#  ('Spotify', 2),
#  ('Search Algorithms', 1),
#  ('Search Analysis', 2),
#  ('Vertical Welding', 1),
#  ('Acute Care Nursing', 2),
#  ('Computer And Network Surveillance', 2),
#  ('Dicing', 1),
#  ('Cargo Systems', 1),
#  ('Message Development', 2),
#  ('Hazardous Waste Disposal', 2),
#  ('Radiosurgery', 1),
#  ('Specman', 1),
#  ('TL 9000 Standard', 1),
#  ('Adobe Marketing Cloud', 1),
#  ('Gel Electrophoresis Of Proteins', 1),
#  ('Ocean Modeling', 2),
#  ('Hidden Markov Model', 2),
#  ('Fisheries Science', 1),
#  ('Population Model', 1),
#  ('Marine Mammals', 1),
#  ('Physical Oceanography', 1),
#  ('Ocean Currents', 2),
#  ('Oracle Procurement', 1),
#  ('Oracle Hyperion Reporting', 2),
#  ('Pipeline Planning', 2),
#  ('AVG (Software)', 1),
#  ('Adware', 2),
#  ('Network Printers', 2),
#  ('Applied Biology', 2),
#  ('Pharmacogenetics', 1),
#  ('Neuropharmacology', 1),
#  ('Electrical Product Design', 1),
#  ('Tournaments', 1),
#  ('File Structure', 2),
#  ('Apollo Client', 1),
#  ('Fuel Cells', 2),
#  ('Ionic Conductivity', 1),
#  ('Density Functional Theory', 2),
#  ('Molecular Dynamics', 2),
#  ('Agricultural Tractors', 2),
#  ('Pesticide Application', 2),
#  ('Handling Instruments', 1),
#  ('Premium Collection', 2),
#  ('Internal Reporting System', 2),
#  ('Custom Widgets', 1),
#  ('Mvc.net', 1),
#  ('ArcObjects', 1),
#  ('ArcGIS Servers', 2),
#  ('Web AppBuilder', 1),
#  ('Ship Transport', 1),
#  ('Cross-Site Request Forgery', 2),
#  ('Database Encryption', 1),
#  ('PVsyst', 2),
#  ('Medical Records Filing', 2),
#  ('Tariff', 1),
#  ('Electrical Documentation', 1),
#  ('Rip Saw', 2),
#  ('Nuclear Fuel Cycle', 2),
#  ('Transition Engineering', 1),
#  ('Aspen Plus', 2),
#  ('Solid Waste Management', 1),
#  ('Adobe Captivate', 2),
#  ('Sales Concepts', 1),
#  ('Data Taxonomy', 1),
#  ('Heat Guns', 1),
#  ('Claims Adjustment', 1),
#  ('Emergency Medical Dispatch', 2),
#  ('Document Camera', 1),
#  ('Hardware Adapters', 1),
#  ('Matterport', 1),
#  ('Gastrointestinal Pathogen Panel', 2),
#  ('Randomization', 2),
#  ('Chart Abstraction', 2),
#  ('Market Profile', 2),
#  ('Airborne Warning And Control Systems', 1),
#  ('Oracle Spatial', 1),
#  ('Continuous Auditing', 1),
#  ('Separately Managed Accounts', 2),
#  ('Customs Broker Licensing', 1),
#  ('Rebase', 2),
#  ('Apple IPod', 2),
#  ('Static Timing Analysis', 2),
#  ('Application Foundation Classes', 1),
#  ('Exercise Therapy', 2),
#  ...]

# %%
q99_spec_skills_counts =[(k,w) for k,w in spec_skill_count.items() if w > 561]

# %%
print(q99_spec_skills_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/r1/0kzylldd4txdz1zgrvxrgpmh0000gn/T/ipykernel_91199/2421030358.py in <module>
# ----> 1 print(q99_spec_skills_counts)
#
# NameError: name 'q99_spec_skills_counts' is not defined
